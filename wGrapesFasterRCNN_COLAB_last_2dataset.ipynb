# %%
# %cd ..
# %cd content
# !wget -O data.zip https://zenodo.org/record/6757555/files/wGrapeUNIPD-DL%20dataset.zip?download=1
# !unzip data.zip
# !rm wGrapeUNIPD-DL\ dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8819.jpg
# !rm wGrapeUNIPD-DL\ dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8819.txt
# !rm wGrapeUNIPD-DL\ dataset/Calibrated_Images/with_Counting/Multiple_Cultivar_BBCH83_13_08_20/_counting.txt
# !wget -O data2.zip https://zenodo.org/record/3361736/files/thsant/wgisd-1.0.0.zip?download=1
# !unzip data2.zip
# Out:
# /
# /content
# --2023-06-24 08:27:43--  https://zenodo.org/record/6757555/files/wGrapeUNIPD-DL%20dataset.zip?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.124.72
# Connecting to zenodo.org (zenodo.org)|188.185.124.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2391373374 (2.2G) [application/octet-stream]
# Saving to: ‘data.zip’
#
# data.zip            100%[===================>]   2.23G  24.1MB/s    in 1m 52s
#
# 2023-06-24 08:29:36 (20.4 MB/s) - ‘data.zip’ saved [2391373374/2391373374]
#
# Archive:  data.zip
#    creating: wGrapeUNIPD-DL dataset/
#    creating: wGrapeUNIPD-DL dataset/Calibrated_Images/
#    creating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/
#    creating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8811.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8811.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8812.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8812.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8813.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8813.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8814.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8814.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8815.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8815.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8816.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8816.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8817.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8817.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8818.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8818.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8819.jpg
#  extracting: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8819.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8822.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8822.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8823.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8823.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8826.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8826.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8827.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8827.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8828.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8828.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8829.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8829.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8830.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8830.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8834.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8834.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8835.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8835.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8836.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8836.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8837.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8837.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8838.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8838.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8839.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8839.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8843.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8843.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8844.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8844.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8845.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8845.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8849.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8849.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8852.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8852.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8853.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8853.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8854.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8854.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8855.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8855.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8856.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8856.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8862.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8862.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8863.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8863.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8864.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8864.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8865.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8865.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8867.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8867.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8869.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8869.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8870.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8870.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8871.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8871.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8872.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8872.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8873.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8873.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8874.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8874.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8875.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8875.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8876.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8876.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8877.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8877.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8880.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8880.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8881.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8881.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8882.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8882.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8883.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8883.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8884.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8884.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8885.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8885.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8886.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8886.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8887.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8887.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8888.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8888.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8889.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8889.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8890.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8890.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8891.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8891.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8892.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8892.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8893.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8893.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8895.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8895.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8899.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8899.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8900.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8900.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8901.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8901.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8902.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8902.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8903.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8903.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8904.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8904.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8905.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8905.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8906.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8906.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8909.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8909.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8910.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8910.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8914.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8914.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8915.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8915.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8916.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8916.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8917.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8917.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8925.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8925.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8926.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8926.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8927.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8927.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8928.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8928.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8929.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8929.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8934.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8934.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8937.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8937.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8938.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8938.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8939.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8939.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8940.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8940.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8941.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8941.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8942.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8942.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8950.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8950.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8951.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8951.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8952.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8952.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8954.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8954.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8957.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8957.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8959.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8959.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8960.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8960.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8961.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8961.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8962.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8962.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8963.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8963.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8964.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8964.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8966.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8966.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8968.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8968.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8969.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8969.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8970.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8970.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8971.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8971.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8972.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8972.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8973.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8973.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8982.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8982.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8983.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8983.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8984.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC8984.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC9012.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC9012.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC9021.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC9021.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC9023.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC9023.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC9097.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC9097.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC9101.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC9101.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC9102.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC9102.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC9103.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC9103.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC9106.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC9106.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC9114.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC9114.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC9127.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC9127.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC9128.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC9128.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC9129.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC9129.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC9130.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC9130.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC9131.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC9131.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC9132.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC9132.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC9133.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Chardonnay_BBCH75_20_06_20/_DSC9133.txt
#    creating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Glera_BBCH75_24_06_20/
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Glera_BBCH75_24_06_20/_DSC9174.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Glera_BBCH75_24_06_20/_DSC9174.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Glera_BBCH75_24_06_20/_DSC9175.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Glera_BBCH75_24_06_20/_DSC9175.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Glera_BBCH75_24_06_20/_DSC9179.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Glera_BBCH75_24_06_20/_DSC9179.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Glera_BBCH75_24_06_20/_DSC9180.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Glera_BBCH75_24_06_20/_DSC9180.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Glera_BBCH75_24_06_20/_DSC9181.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Glera_BBCH75_24_06_20/_DSC9181.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Glera_BBCH75_24_06_20/_DSC9187.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Glera_BBCH75_24_06_20/_DSC9187.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Glera_BBCH75_24_06_20/_DSC9189.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Glera_BBCH75_24_06_20/_DSC9189.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Glera_BBCH75_24_06_20/_DSC9190.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Glera_BBCH75_24_06_20/_DSC9190.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Glera_BBCH75_24_06_20/_DSC9192.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Glera_BBCH75_24_06_20/_DSC9192.txt
#    creating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Glera_BBCH83_07_08_20/
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Glera_BBCH83_07_08_20/ANMP0044.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Glera_BBCH83_07_08_20/ANMP0044.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Glera_BBCH83_07_08_20/ANMP0045.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Glera_BBCH83_07_08_20/ANMP0045.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Glera_BBCH83_07_08_20/ANMP0046.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Glera_BBCH83_07_08_20/ANMP0046.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Glera_BBCH83_07_08_20/ANMP0047.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Glera_BBCH83_07_08_20/ANMP0047.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Glera_BBCH83_07_08_20/ANMP0048.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Glera_BBCH83_07_08_20/ANMP0048.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Glera_BBCH83_07_08_20/ANMP0049.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Glera_BBCH83_07_08_20/ANMP0049.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Glera_BBCH83_07_08_20/ANMP0050.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Glera_BBCH83_07_08_20/ANMP0050.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Glera_BBCH83_07_08_20/ANMP0052.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Glera_BBCH83_07_08_20/ANMP0052.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Glera_BBCH83_07_08_20/ANMP0054.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Glera_BBCH83_07_08_20/ANMP0054.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Glera_BBCH83_07_08_20/ANMP0055.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Glera_BBCH83_07_08_20/ANMP0055.txt
#    creating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9297.JPG
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9297.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9298.JPG
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9298.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9300.JPG
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9300.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9301.JPG
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9301.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9302.JPG
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9302.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9303.JPG
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9303.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9304.JPG
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9304.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9305.JPG
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9305.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9306.JPG
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9306.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9307.JPG
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9307.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9308.JPG
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9308.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9309.JPG
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9309.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9310.JPG
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9310.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9311.JPG
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9311.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9312.JPG
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9312.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9313.JPG
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9313.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9314.JPG
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9314.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9315.JPG
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9315.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9316.JPG
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9316.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9317.JPG
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9317.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9318.JPG
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9318.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9319.JPG
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9319.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9320.JPG
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9320.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9321.JPG
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9321.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9322.JPG
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9322.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9323.JPG
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9323.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9324.JPG
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9324.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9325.JPG
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9325.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9326.JPG
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9326.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9327.JPG
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH81_5_08_20/_DSC9327.txt
#    creating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH83_12_08_20/
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH83_12_08_20/ANMP0000.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH83_12_08_20/ANMP0000.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH83_12_08_20/ANMP0002.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH83_12_08_20/ANMP0002.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH83_12_08_20/ANMP0003.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH83_12_08_20/ANMP0003.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH83_12_08_20/ANMP0004.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH83_12_08_20/ANMP0004.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH83_12_08_20/ANMP0005.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH83_12_08_20/ANMP0005.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH83_12_08_20/ANMP0006.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH83_12_08_20/ANMP0006.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH83_12_08_20/ANMP0007.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Multiple_Cultivar_BBCH83_12_08_20/ANMP0007.txt
#    creating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH75_22_06_20/
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH75_22_06_20/IMG_2128.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH75_22_06_20/IMG_2128.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH75_22_06_20/IMG_2130.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH75_22_06_20/IMG_2130.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH75_22_06_20/IMG_2132.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH75_22_06_20/IMG_2132.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH75_22_06_20/IMG_2134.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH75_22_06_20/IMG_2134.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH75_22_06_20/IMG_2136.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH75_22_06_20/IMG_2136.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH75_22_06_20/IMG_2138.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH75_22_06_20/IMG_2138.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH75_22_06_20/IMG_2139.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH75_22_06_20/IMG_2139.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH75_22_06_20/IMG_2141.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH75_22_06_20/IMG_2141.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH75_22_06_20/IMG_2143.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH75_22_06_20/IMG_2143.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH75_22_06_20/IMG_2145.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH75_22_06_20/IMG_2145.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH75_22_06_20/IMG_2184.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH75_22_06_20/IMG_2184.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH75_22_06_20/IMG_2186.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH75_22_06_20/IMG_2186.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH75_22_06_20/IMG_2188.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH75_22_06_20/IMG_2188.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH75_22_06_20/IMG_2190.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH75_22_06_20/IMG_2190.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH75_22_06_20/IMG_2208.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH75_22_06_20/IMG_2208.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH75_22_06_20/IMG_2210.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH75_22_06_20/IMG_2210.txt
#    creating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH77_13_07_20/
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH77_13_07_20/IMG_2545.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH77_13_07_20/IMG_2545.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH77_13_07_20/IMG_2547.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH77_13_07_20/IMG_2547.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH77_13_07_20/IMG_2548.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH77_13_07_20/IMG_2548.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH77_13_07_20/IMG_2549.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH77_13_07_20/IMG_2549.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH77_13_07_20/IMG_2550.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH77_13_07_20/IMG_2550.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH77_13_07_20/IMG_2551.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH77_13_07_20/IMG_2551.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH77_13_07_20/IMG_2553.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH77_13_07_20/IMG_2553.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH77_13_07_20/IMG_2554.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH77_13_07_20/IMG_2554.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH77_13_07_20/IMG_2555.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH77_13_07_20/IMG_2555.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH77_13_07_20/IMG_2556.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH77_13_07_20/IMG_2556.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH77_13_07_20/IMG_2557.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH77_13_07_20/IMG_2557.txt
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH77_13_07_20/IMG_2558.jpg
#   inflating: wGrapeUNIPD-DL dataset/Calibrated_Images/without_Conting/Trebbiano_BBCH77_13_07_20/IMG_2558.txt
# ...
#   inflating: thsant-wgisd-ab223e5/original_resolution/CFR_1644.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CFR_1645.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CFR_1646.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CFR_1647.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CFR_1648.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CFR_1650.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CFR_1651.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CFR_1652.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CFR_1653.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CFR_1654.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CFR_1655.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CFR_1656.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CFR_1657.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CFR_1658.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CFR_1659.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CFR_1660.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CFR_1661.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CFR_1662.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CFR_1663.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CFR_1664.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CFR_1666.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CFR_1667.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CFR_1668.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CFR_1670.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CFR_1671.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CFR_1672.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CFR_20180427_141010086_HDR.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CFR_20180427_141030745_HDR.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CFR_20180427_141059738_HDR.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CFR_20180427_141115778_HDR.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CFR_20180427_141119803_HDR.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CFR_20180427_141128570.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CFR_20180427_141134599.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CFR_20180427_141150696.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CFR_20180427_141158495.jpg
#  extracting: thsant-wgisd-ab223e5/original_resolution/CFR_20180427_141215627.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CFR_20180427_141224656.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CFR_20180427_141228722.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CFR_20180427_141236326.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CFR_20180427_141239085.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CFR_20180427_141254316_HDR.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_1865.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_1866.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_1867.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_1868.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_1869.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_1870.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_1871.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_1872.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_1873.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_1874.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_1876.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_1877.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_1878.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_1880.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_1881.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_1882.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_1883.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_1884.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_1886.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_1887.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_1889.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_1890.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_1891.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_1892.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_1893.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_1894.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_1896.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_1897.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_1898.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_1899.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_1900.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_1901.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_1902.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_1903.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_1904.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_1905.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_1906.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_1907.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_1908.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_1909.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_1911.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_1912.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_20180427_144507419.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_20180427_144513954.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_20180427_144521946.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_20180427_144528920.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_20180427_144535647.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_20180427_144548550.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_20180427_144556277.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_20180427_144602780.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_20180427_144615644.jpg
#  extracting: thsant-wgisd-ab223e5/original_resolution/CSV_20180427_144622111_HDR.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_20180427_144714850_HDR.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_20180427_144723166_HDR.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_20180427_144732784_HDR.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_20180427_144743364_HDR.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/CSV_20180427_144848357.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1929.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1930.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1931.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1932.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1933.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1934.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1935.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1936.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1937.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1938.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1939.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1940.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1941.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1942.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1943.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1944.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1945.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1946.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1947.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1948.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1949.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1950.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1951.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1952.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1953.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1954.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1955.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1956.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1957.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1958.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1959.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1960.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1961.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1962.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1963.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1964.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1965.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1966.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1967.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1968.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1969.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1970.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1971.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1972.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1973.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1974.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1975.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1976.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1977.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_1978.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_20180427_151818928.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_20180427_151832492.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_20180427_151848752.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_20180427_151905850_HDR.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_20180427_151954938_HDR.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_20180427_152010406_HDR.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_20180427_152027593_HDR.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_20180427_152106643_HDR.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_20180427_152141327.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_20180427_152158290_HDR.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_20180427_152220515_HDR.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_20180427_152312131_HDR.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_20180427_152328332_HDR.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_20180427_152404735_HDR.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SVB_20180427_152414932_HDR.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1232.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1233.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1236.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1238.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1239.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1241.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1243.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1247.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1251.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1253.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1255.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1260.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1262.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1264.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1265.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1268.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1269.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1271.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1273.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1275.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1278.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1280.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1285.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1289.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1291.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1292.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1294.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1297.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1300.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1304.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1310.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1311.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1312.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1314.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1316.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1318.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1320.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1322.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1324.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1326.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1332.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1333.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1334.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1336.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1338.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1340.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1342.jpg
#   inflating: thsant-wgisd-ab223e5/original_resolution/SYH_2017-04-27_1344.jpg
#   inflating: thsant-wgisd-ab223e5/test.txt
#   inflating: thsant-wgisd-ab223e5/test_masked.txt
#   inflating: thsant-wgisd-ab223e5/train.txt
#   inflating: thsant-wgisd-ab223e5/train_masked.txt

# %%
# %cd ..
# !rm -r /vision

# !rm -r /datasets/wgisd/
# !rm -r /datasets/grapes/
# !mkdir /datasets

# !mkdir /datasets/wgisd/
# !mkdir /datasets/grapes/
# !mkdir /datasets/wgisd/images/
# !mkdir /datasets/grapes/images/
# !mkdir /datasets/wgisd/labels/
# !mkdir /datasets/grapes/labels/
# !mkdir /datasets/wgisd/labels/train
# !mkdir /datasets/grapes/labels/train
# !mkdir /datasets/wgisd/labels/val
# !mkdir /datasets/grapes/labels/val
# !mkdir /datasets/wgisd/images/train
# !mkdir /datasets/grapes/images/train
# !mkdir /datasets/wgisd/images/val
# !mkdir /datasets/grapes/images/val
# !cp /content/wGrapeUNIPD-DL\ dataset/Calibrated_Images/*/*/*.txt /datasets/grapes/labels/train/
# !cp /content/wGrapeUNIPD-DL\ dataset/Calibrated_Images/*/*/*.jpg /datasets/grapes/images/train/
# !cp /content/wGrapeUNIPD-DL\ dataset/Calibrated_Images/*/*/*.JPG /datasets/grapes/images/train/

# !cp /content/thsant-wgisd-ab223e5/data/*.txt /datasets/wgisd/labels/train/
# !cp /content/thsant-wgisd-ab223e5/data/*.jpg /datasets/wgisd/images/train/
# !cp /content/thsant-wgisd-ab223e5/data/*.JPG /datasets/wgisd/images/train/

# !rm /datasets/grapes/labels/train/_DSC8819.txt
# !rm /datasets/grapes/images/train/_DSC8819.jpg
# Out:
# /
# rm: cannot remove '/vision': No such file or directory
# rm: cannot remove '/datasets/wgisd/': No such file or directory
# rm: cannot remove '/datasets/grapes/': No such file or directory
# cp: cannot stat '/content/thsant-wgisd-ab223e5/data/*.JPG': No such file or directory
# rm: cannot remove '/datasets/grapes/labels/train/_DSC8819.txt': No such file or directory
# rm: cannot remove '/datasets/grapes/images/train/_DSC8819.jpg': No such file or directory

# %%
# %cd ..
import os
import random
lst = sorted(os.listdir("/datasets/grapes/labels/train/"))
lst_imgs = sorted(os.listdir("/datasets/grapes/images/train/"))

indici= random.sample(range(0, len(lst)-1), int(len(lst)*0.2))
print(len(lst), len(lst_imgs))
print(indici)
for i in indici:
  str_lab= "/datasets/grapes/labels/train/"+lst[i]
  str_img= "/datasets/grapes/images/train/"+lst_imgs[i]
  # !mv $str_lab /datasets/grapes/labels/val/
  # !mv $str_img /datasets/grapes/images/val/

lst = sorted(os.listdir("/datasets/wgisd/labels/train/"))
lst_imgs = sorted(os.listdir("/datasets/wgisd/images/train/"))

indici= random.sample(range(0, len(lst)-1), int(len(lst)*0.2))
print(len(lst), len(lst_imgs))
print(indici)
for i in indici:
  str_lab= "/datasets/wgisd/labels/train/"+lst[i]
  str_img= "/datasets/wgisd/images/train/"+lst_imgs[i]
  # !mv $str_lab /datasets/wgisd/labels/val/
  # !mv $str_img /datasets/wgisd/images/val/

print(len(os.listdir("/datasets/grapes/labels/train")), len(os.listdir("/datasets/grapes/labels/val")))
# Out:
# /
# 270 270
# [8, 43, 240, 76, 70, 111, 141, 80, 45, 185, 147, 202, 12, 177, 226, 69, 20, 94, 258, 255, 117, 64, 134, 205, 66, 77, 250, 108, 184, 231, 88, 113, 29, 194, 230, 35, 145, 140, 125, 252, 57, 204, 155, 27, 263, 168, 239, 216, 74, 153, 120, 154, 173, 131]
# 300 300
# [97, 219, 54, 155, 142, 218, 56, 203, 108, 159, 45, 84, 137, 236, 16, 290, 258, 136, 21, 287, 18, 121, 251, 183, 272, 210, 12, 175, 192, 133, 127, 76, 55, 297, 40, 217, 59, 240, 197, 151, 254, 248, 32, 89, 57, 6, 292, 208, 176, 214, 102, 13, 228, 179, 215, 139, 152, 61, 86, 233]
# 216 54

# %%
# %%shell
# # Download TorchVision repo to use some files from
# # references/detection
# git clone https://github.com/pytorch/vision.git
# cd vision
# git checkout v0.15.1
#
# cp references/detection/utils.py ../
# cp references/detection/transforms.py ../
# cp references/detection/coco_eval.py ../
# cp references/detection/engine.py ../
# cp references/detection/coco_utils.py ../
# Out:
# Cloning into 'vision'...
# remote: Enumerating objects: 344212, done.
# remote: Counting objects: 100% (60444/60444), done.
# remote: Compressing objects: 100% (1557/1557), done.
# remote: Total 344212 (delta 59447), reused 59705 (delta 58844), pack-reused 283768
# Receiving objects: 100% (344212/344212), 689.38 MiB | 36.52 MiB/s, done.
# Resolving deltas: 100% (317298/317298), done.
# Note: switching to 'v0.15.1'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 42759b1cc8 Version number bump for vision (#7419)

# %%
# !pip install torch==2.0.0+cu118 torchvision==0.15.1+cu118 torchaudio==2.0.1 --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch==2.0.0+cu118
#   Downloading https://download.pytorch.org/whl/cu118/torch-2.0.0%2Bcu118-cp310-cp310-linux_x86_64.whl (2267.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 GB 740.7 kB/s eta 0:00:00
# Collecting torchvision==0.15.1+cu118
#   Downloading https://download.pytorch.org/whl/cu118/torchvision-0.15.1%2Bcu118-cp310-cp310-linux_x86_64.whl (6.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 102.0 MB/s eta 0:00:00
# Collecting torchaudio==2.0.1
#   Downloading https://download.pytorch.org/whl/cu118/torchaudio-2.0.1%2Bcu118-cp310-cp310-linux_x86_64.whl (4.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 101.2 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0+cu118) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0+cu118) (4.6.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0+cu118) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0+cu118) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0+cu118) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0+cu118) (2.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision==0.15.1+cu118) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision==0.15.1+cu118) (2.27.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision==0.15.1+cu118) (8.4.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.0+cu118) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.0+cu118) (16.0.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.0.0+cu118) (2.1.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.15.1+cu118) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.15.1+cu118) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.15.1+cu118) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.15.1+cu118) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.0.0+cu118) (1.3.0)
# Installing collected packages: torch, torchvision, torchaudio
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.1+cu118
#     Uninstalling torch-2.0.1+cu118:
#       Successfully uninstalled torch-2.0.1+cu118
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.15.2+cu118
#     Uninstalling torchvision-0.15.2+cu118:
#       Successfully uninstalled torchvision-0.15.2+cu118
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.0.2+cu118
#     Uninstalling torchaudio-2.0.2+cu118:
#       Successfully uninstalled torchaudio-2.0.2+cu118
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchdata 0.6.1 requires torch==2.0.1, but you have torch 2.0.0+cu118 which is incompatible.
# torchtext 0.15.2 requires torch==2.0.1, but you have torch 2.0.0+cu118 which is incompatible.
# Successfully installed torch-2.0.0+cu118 torchaudio-2.0.1+cu118 torchvision-0.15.1+cu118

# %%
# !pip3 install albumentations==1.3.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting albumentations==1.3.0
#   Downloading albumentations-1.3.0-py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.5/123.5 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.11.1 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.3.0) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from albumentations==1.3.0) (1.10.1)
# Requirement already satisfied: scikit-image>=0.16.1 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.3.0) (0.19.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from albumentations==1.3.0) (6.0)
# Requirement already satisfied: qudida>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.3.0) (0.0.4)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from albumentations==1.3.0) (4.7.0.72)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from qudida>=0.0.4->albumentations==1.3.0) (1.2.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from qudida>=0.0.4->albumentations==1.3.0) (4.6.3)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations==1.3.0) (3.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations==1.3.0) (8.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations==1.3.0) (2.25.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations==1.3.0) (2023.4.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations==1.3.0) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations==1.3.0) (23.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations==1.3.0) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations==1.3.0) (3.1.0)
# Installing collected packages: albumentations
#   Attempting uninstall: albumentations
#     Found existing installation: albumentations 1.2.1
#     Uninstalling albumentations-1.2.1:
#       Successfully uninstalled albumentations-1.2.1
# Successfully installed albumentations-1.3.0

# %%
# %cd ..
import os
import cv2
import numpy as np
import torch
from PIL import Image
import glob
import torchvision.transforms as T
import torchvision
import math
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from albumentations.core.composition import Compose
from albumentations.pytorch.transforms import ToTensorV2
import torch.nn as nn
import albumentations as A

import random

DEVICE = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
BATCH_SIZE = 1
EPOCHS = 5
IMAGE_WIDTH = 1216
IMAGE_HEIGHT = 1216
FILES_DIR_WGISD = "/datasets/wgisd"
FILES_DIR_WGRAPE = "/datasets/grapes"
print(DEVICE)

def get_transform(train):
  if train:
    return Compose(
      [
        A.HorizontalFlip(p=0.5),
        A.RandomScale(scale_limit=0.4, interpolation = cv2.INTER_LINEAR, p=0.5),
        A.BBoxSafeRandomCrop(p=0.5),
        A.ColorJitter(random.uniform(0,0.2), random.uniform(0,0.2), random.uniform(0,0.2), random.uniform(0,0.2), p=0.5),
        ToTensorV2(p = 1.0)
      ],
      bbox_params={'format': 'pascal_voc', 'label_fields': ['labels']}
    )
  else:
    return Compose(
      [
        ToTensorV2(p=1.0)
      ],
      bbox_params={'format': 'pascal_voc', 'label_fields': ['labels']}
    )
# Out:
# /
# cuda

# %%
class GrapeDataset(torch.utils.data.Dataset):
    def __init__(self, root, width, height, transforms = None):
        self.transforms = transforms
        self.root = root

        self.width = width
        self.height = height

        self.imgs=[]
        boxes_files=[]
        for root, dirs, files in os.walk(self.root):
            for file in files:
                if file.endswith(".txt") and not file.startswith("_counting"):
                    boxes_files.append(os.path.join(root, file))
                if file.endswith(".jpg") or file.endswith(".JPG")  :
                    self.imgs.append(os.path.join(root, file))
                if file.startswith("_counting"):
                   self.conting_file = os.path.join(root, "_counting.txt")
        self.imgs = sorted(self.imgs)
        boxes_files = sorted(boxes_files)
        self.boxes = boxes_files

    def __getitem__(self, idx):
        # get image and boxes
        img_path = self.imgs[idx]
        box_path = self.boxes[idx]
        # image elaboration
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(np.float32)
        img = cv2.resize(img, (self.width, self.height), cv2.INTER_AREA)
        img /= 255.0

        height, width, _ = img.shape
        # note that we haven't converted the mask to RGB,
        # because each color corresponds to a different instance
        # with 0 being background
        labels=[]
        boxes=[]
        with open(box_path) as f:
            for line in f:
                labels.append(1)

                elems=[float(x) for x in line.split(' ')]

                x_center = int(elems[1] * width)
                y_center = int(elems[2] * height)
                box_wt = int(elems[3] * width)
                box_ht = int(elems[4] * height)

                x_min = max(0.0, x_center - box_wt/2)
                x_max  = min(width, x_center + box_wt/2)
                y_min = max(0.0, y_center - box_ht/2)
                y_max  = min(height, y_center + box_ht/2)

                if x_min>=x_max:
                  x_min=x_max-0.001
                if y_min>=y_max:
                  y_min=y_max-0.001

                boxes.append([x_min, y_min, x_max, y_max])

        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        labels= torch.as_tensor(labels, dtype=torch.int64)
        iscrowd= torch.zeros((boxes.shape[0],),dtype=torch.int64)
        area = (boxes[:,3]-boxes[:,1])*(boxes[:,2]-boxes[:,0])
        target={}
        target["boxes"] = boxes
        target["area"] = area
        target["labels"]= labels
        target["iscrowd"] = iscrowd
        image_id = torch.tensor([idx])
        target["image_id"] = image_id

        if self.transforms:
            sample = self.transforms(image = img,
                                bboxes = target['boxes'],
                                labels = labels)
            img = sample['image']
            target['boxes'] = torch.Tensor(sample['bboxes'])

        return img, target

    def __len__(self):
        return len(self.imgs)

# %%
def plot_img_bbox(img, target, prediction):
  # plot the image and bboxes
  # Bounding boxes are defined as follows: x-min y-min width height
  fig, ax = plt.subplots(1,1)
  fig.set_size_inches(5,5)
  img=img.permute(1,2,0)
  ax.imshow(img)

  for box in (target['boxes']):
    x, y, width, height  = box[0], box[1], box[2]-box[0], box[3]-box[1]
    rect = patches.Rectangle(
      (x, y),
      width, height,
      linewidth = 2,
      edgecolor = 'black',
      facecolor = 'none'
    )
    # Draw the bounding box on top of the image
    ax.add_patch(rect)

  for box in (prediction['boxes']):
    x, y, width, height  = box[0], box[1], box[2]-box[0], box[3]-box[1]
    rect = patches.Rectangle(
      (x, y),
      width, height,
      linewidth = 1,
      edgecolor = 'r',
      facecolor = 'none'
    )
    # Draw the bounding box on top of the image
    ax.add_patch(rect)
  plt.show()


def plot_img_bbox_alone(img, target):
  # plot the image and bboxes
  # Bounding boxes are defined as follows: x-min y-min width height
  fig, ax = plt.subplots(1,1)
  fig.set_size_inches(5,5)
  img=img.permute(1,2,0)
  ax.imshow(img)

  for box in (target['boxes']):
    x, y, width, height  = box[0], box[1], box[2]-box[0], box[3]-box[1]
    rect = patches.Rectangle(
      (x, y),
      width, height,
      linewidth = 2,
      edgecolor = 'black',
      facecolor = 'none'
    )
    # Draw the bounding box on top of the image
    ax.add_patch(rect)

  plt.show()

files_path=FILES_DIR_WGISD
dataset_train = GrapeDataset(files_path, IMAGE_WIDTH, IMAGE_HEIGHT, get_transform(train=True))
dataset_test = GrapeDataset(files_path, IMAGE_WIDTH, IMAGE_HEIGHT,  get_transform(train=False))
print("Number of Dataset Images: ", len(dataset_test))
n = random.randint(0,len(dataset_test)-1)
img, target = dataset_train[n]
plot_img_bbox_alone(img, target)
img, target = dataset_test[n]
plot_img_bbox_alone(img, target)

dataset_wgrape = GrapeDataset(FILES_DIR_WGRAPE, IMAGE_WIDTH, IMAGE_HEIGHT, transforms=get_transform(train=True))
dataset_test_wgrape = GrapeDataset(FILES_DIR_WGRAPE, IMAGE_WIDTH, IMAGE_HEIGHT,  transforms=get_transform(train=False))

dataset_wgisd = GrapeDataset(FILES_DIR_WGISD, IMAGE_WIDTH, IMAGE_HEIGHT, transforms=get_transform(train=True))
dataset_test_wgisd = GrapeDataset(FILES_DIR_WGISD, IMAGE_WIDTH, IMAGE_HEIGHT,  transforms=get_transform(train=False))
# Out:
# Number of Dataset Images:  300

# %%
from tqdm.notebook import tqdm
import time
import torch
import numpy

loss_objectness = []
loss_box_reg = []
loss_classifier= []

def train_epoch(model, optimizer, data_loader, device, epoch):
        model.train()

        for i, (images, targets) in (tepoch := tqdm(enumerate(data_loader), unit="batch", total=len(data_loader))):
            tepoch.set_description(f"Epoch {epoch}")
            if len(targets)==0:
                  continue
            # Step 1: send the image to the required device.
            # Images is a list of B images (where B = batch_size of the DataLoader).
            images = list(img.to(device) for img in images)
            # Step 2: send each target to the required device
            # Targets is a dictionary of metadata. each (k,v) pair is a metadata
            # required for training.
            targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

            model_time = time.time()
            loss_dict=model(images, targets)

            model_time = time.time() - model_time
            loss_objectness.append(loss_dict["loss_objectness"].cpu().detach().numpy())
            loss_box_reg.append(loss_dict["loss_box_reg"].cpu().detach().numpy())
            loss_classifier.append(loss_dict["loss_classifier"].cpu().detach().numpy())
            # Step 3. backward on loss.
            # Normally, you would obtain the loss from the model.forward()
            # and then just call .bacward() on it.
            # In this case, for each task, you have a different loss, due to
            # different error metrics adopted by the tasks.
            # One typical approach is to combine all the losses to one single loss,
            # and then then backward that single loss.
            # In this way you can adjust the weight of the different tasks,
            # multiplying each loss for a hyperparemeter.
            # E.G.:
            #       final_loss = loss_1 + gamma*(alpha*loss_2 + beta*loss_3)
            # In this case, we want to sum up all the losses.
            losses = sum(loss for loss in loss_dict.values())
            optimizer.zero_grad()
            losses.backward()
            optimizer.step()
            tepoch.set_postfix(loss=losses.item())

# %%
import utils
# use our dataset and defined transformations
def redefine_dataset(path, size_image_width, size_image_height):
    dataset = GrapeDataset(path, size_image_width, size_image_height, transforms=get_transform(train=True))
    dataset_test = GrapeDataset(path, size_image_width, size_image_height,  transforms=get_transform(train=False))

    # train test split
    torch.manual_seed(random.randint(0,100))
    indices = torch.randperm(len(dataset)).tolist()
    test_split = 0.2
    print(indices)
    tsize = int(len(dataset)*test_split)
    dataset = torch.utils.data.Subset(dataset, indices[:-tsize])
    print(len(dataset))
    dataset_test = torch.utils.data.Subset(dataset_test, indices[-tsize:])
    print(len(dataset_test))

    # define training and validation data loaders
    data_loader = torch.utils.data.DataLoader(
        dataset,
        batch_size=BATCH_SIZE,
        shuffle=True,
        num_workers=0,
        collate_fn=utils.collate_fn,
    )

    data_loader_test = torch.utils.data.DataLoader(
        dataset_test,
        batch_size=BATCH_SIZE,
        shuffle=False,
        num_workers=0,
        collate_fn=utils.collate_fn,
    )

    return data_loader, data_loader_test


data_loader_wgisd, data_loader_test_wgisd = redefine_dataset(FILES_DIR_WGISD, IMAGE_WIDTH, IMAGE_HEIGHT)
print(str(len(data_loader_wgisd))+" "+str(len(data_loader_test_wgisd)))
data_loader_wgrape, data_loader_test_wgrape = redefine_dataset(FILES_DIR_WGRAPE, IMAGE_WIDTH, IMAGE_HEIGHT)
print(str(len(data_loader_wgrape))+" "+str(len(data_loader_test_wgrape)))
# Out:
# [174, 34, 254, 281, 80, 239, 222, 255, 125, 152, 116, 73, 192, 218, 36, 165, 135, 205, 97, 99, 278, 151, 271, 219, 47, 223, 209, 188, 150, 28, 33, 9, 196, 18, 25, 256, 243, 228, 201, 91, 16, 167, 159, 212, 252, 260, 156, 280, 251, 1, 23, 117, 220, 230, 175, 173, 92, 148, 60, 114, 86, 122, 63, 134, 259, 126, 285, 98, 69, 297, 267, 295, 208, 115, 197, 131, 29, 3, 43, 53, 49, 65, 162, 183, 176, 37, 45, 269, 193, 182, 275, 263, 273, 71, 206, 128, 241, 121, 74, 27, 160, 161, 136, 247, 13, 163, 62, 214, 102, 221, 22, 299, 144, 231, 283, 83, 194, 84, 41, 21, 246, 93, 72, 276, 157, 238, 296, 2, 171, 236, 15, 216, 226, 129, 166, 198, 210, 85, 141, 5, 248, 0, 147, 154, 52, 277, 105, 279, 257, 124, 20, 24, 50, 292, 103, 290, 75, 35, 250, 233, 77, 110, 68, 185, 138, 132, 90, 213, 287, 199, 64, 42, 101, 204, 54, 119, 153, 111, 245, 56, 11, 67, 79, 61, 8, 191, 264, 4, 272, 127, 39, 139, 266, 224, 26, 258, 104, 270, 195, 12, 235, 261, 48, 227, 200, 113, 187, 44, 6, 107, 298, 94, 229, 262, 146, 274, 203, 202, 130, 178, 87, 108, 225, 17, 286, 30, 123, 282, 207, 57, 234, 32, 181, 137, 40, 170, 284, 180, 7, 112, 164, 169, 242, 70, 232, 133, 142, 237, 268, 179, 155, 81, 177, 293, 100, 265, 244, 149, 78, 118, 82, 143, 288, 172, 46, 217, 59, 106, 31, 211, 190, 249, 109, 55, 291, 38, 158, 76, 58, 184, 186, 14, 96, 215, 168, 51, 189, 95, 294, 120, 89, 10, 19, 66, 88, 253, 145, 240, 140, 289]
# 240
# 60
# 240 60
# [31, 218, 115, 155, 139, 13, 194, 81, 169, 2, 143, 104, 176, 119, 134, 99, 12, 58, 110, 42, 109, 167, 216, 69, 86, 230, 191, 11, 80, 247, 19, 113, 140, 135, 190, 219, 94, 7, 203, 204, 56, 35, 186, 183, 41, 246, 60, 213, 75, 192, 181, 122, 187, 210, 101, 73, 106, 121, 34, 102, 260, 44, 259, 118, 46, 201, 114, 38, 79, 267, 209, 150, 145, 32, 208, 220, 125, 14, 159, 227, 107, 256, 126, 49, 138, 174, 269, 48, 28, 222, 170, 258, 120, 68, 254, 217, 131, 116, 27, 206, 255, 265, 250, 193, 237, 240, 165, 185, 54, 157, 141, 85, 61, 214, 112, 225, 173, 129, 263, 17, 163, 88, 18, 182, 105, 168, 103, 24, 160, 36, 66, 98, 242, 136, 55, 20, 137, 59, 188, 175, 158, 200, 132, 231, 23, 10, 72, 151, 195, 1, 76, 123, 224, 71, 211, 235, 223, 43, 78, 149, 266, 198, 64, 166, 70, 262, 97, 245, 196, 0, 178, 50, 161, 142, 232, 117, 96, 108, 92, 87, 249, 221, 184, 91, 8, 228, 229, 264, 89, 261, 146, 244, 100, 9, 124, 253, 130, 179, 252, 127, 26, 83, 74, 234, 90, 212, 40, 238, 156, 133, 53, 202, 57, 33, 243, 5, 84, 162, 148, 207, 144, 171, 63, 199, 95, 241, 22, 172, 67, 82, 77, 65, 164, 15, 39, 153, 257, 154, 189, 30, 251, 233, 248, 239, 4, 52, 177, 93, 3, 180, 25, 111, 128, 147, 62, 51, 205, 152, 45, 226, 16, 29, 268, 236, 215, 37, 197, 21, 6, 47]
# 216
# 54
# 216 54

# %%
from torchvision.models.detection import FasterRCNN
from torchvision.models.detection.rpn import AnchorGenerator
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection.faster_rcnn import FastRCNNConvFCHead
from torchvision.models.detection.faster_rcnn import RPNHead
from torchvision.models.detection.backbone_utils import resnet_fpn_backbone

def create_model(num_classes, backbone="resnet_50"):

    model=None
    if backbone == "mobilenet":
        vgg_net = torchvision.models.mobilenet_v2(pretrained=True)
        ft_backbone = vgg_net.features
        ft_backbone.out_channels = 1280
        anchor_generator = AnchorGenerator(
        sizes=((32, 64, 128, 256, 512),),
        aspect_ratios=((0.5, 1.0, 2.0),)
        )
        # Feature maps to perform RoI cropping.
        # If backbone returns a Tensor, `featmap_names` is expected to
        # be [0]. We can choose which feature maps to use.
        roi_pooler = torchvision.ops.MultiScaleRoIAlign(
            featmap_names=['0'],
            output_size=7,
            sampling_ratio=2
        )
        # Final Faster RCNN model.
        model = FasterRCNN(
            backbone=ft_backbone,
            num_classes=num_classes,
            rpn_anchor_generator=anchor_generator,
            box_roi_pool=roi_pooler
        )
    elif backbone == "vgg16":
        vgg_net = torchvision.models.vgg16(pretrained=True)
        ft_backbone = vgg_net.features
        ft_backbone.out_channels = 512
        anchor_generator = AnchorGenerator(
        sizes=((32, 64, 128, 256, 512),),
        aspect_ratios=((0.5, 1.0, 2.0),)
        )
        # Feature maps to perform RoI cropping.
        # If backbone returns a Tensor, `featmap_names` is expected to
        # be [0]. We can choose which feature maps to use.
        roi_pooler = torchvision.ops.MultiScaleRoIAlign(
            featmap_names=['0'],
            output_size=7,
            sampling_ratio=2
        )
        # Final Faster RCNN model.
        model = FasterRCNN(
            backbone=ft_backbone,
            num_classes=num_classes,
            rpn_anchor_generator=anchor_generator,
            box_roi_pool=roi_pooler
        )

    elif backbone == "vgg19":
        vgg_net = torchvision.models.vgg19(pretrained=True)
        ft_backbone = vgg_net.features
        ft_backbone.out_channels = 512
        anchor_generator = AnchorGenerator(
        sizes=((32, 64, 128, 256, 512),),
        aspect_ratios=((0.5, 1.0, 2.0),)
        )
        # Feature maps to perform RoI cropping.
        # If backbone returns a Tensor, `featmap_names` is expected to
        # be [0]. We can choose which feature maps to use.
        roi_pooler = torchvision.ops.MultiScaleRoIAlign(
            featmap_names=['0'],
            output_size=7,
            sampling_ratio=2
        )
        # Final Faster RCNN model.
        model = FasterRCNN(
            backbone=ft_backbone,
            num_classes=num_classes,
            rpn_anchor_generator=anchor_generator,
            box_roi_pool=roi_pooler
        )
    elif backbone == "resnet18_fpn":
        backbone = resnet_fpn_backbone('resnet18', True)
        model = FasterRCNN(backbone, num_classes)
        in_features = model.roi_heads.box_predictor.cls_score.in_features
        model.roi_heads.box_predictor = FastRCNNPredictor(in_features, 2)

    elif backbone == "resnet50_fpn":
        backbone = resnet_fpn_backbone('resnet50', True)
        model = FasterRCNN(backbone, num_classes)
        in_features = model.roi_heads.box_predictor.cls_score.in_features
        model.roi_heads.box_predictor = FastRCNNPredictor(in_features, 2)

    elif backbone == "resnet101_fpn":
        backbone = resnet_fpn_backbone('resnet101', True)
        model = FasterRCNN(backbone, num_classes)
        in_features = model.roi_heads.box_predictor.cls_score.in_features
        model.roi_heads.box_predictor = FastRCNNPredictor(in_features, 2)
    else:
        print("Error Wrong unsupported Backbone")
        return

    return model

# %%
import random
import os
import cv2
import numpy as np
import torch
from PIL import Image
import glob
import torchvision.transforms as T
import torchvision
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import torch
from torchvision import transforms as torchtrans
from engine import train_one_epoch, evaluate
import utils
import torchvision.transforms as T
import torchvision
from torchvision.models.detection import FasterRCNN
from torchvision.models.detection.rpn import AnchorGenerator
from torchvision.models.detection.backbone_utils import resnet_fpn_backbone
from torchvision.models.detection import retinanet_resnet50_fpn_v2
from torchvision.models.detection import RetinaNet, RetinaNet_ResNet50_FPN_V2_Weights, FasterRCNN_ResNet50_FPN_Weights, FasterRCNN_ResNet50_FPN_V2_Weights
from torchvision.models import ResNet50_Weights, resnet101
from torchvision.models.detection.retinanet import RetinaNetClassificationHead, RetinaNetRegressionHead
from functools import partial
from tqdm.notebook import tqdm
import gc

# train on gpu if available

num_classes = 2 # one class (class 0) is dedicated to the "background"
backbones=["mobilenet","vgg16","vgg19","resnet18_fpn", "resnet50_fpn", "resnet101_fpn"]
# backbones=["resnet50_fpn"]
coco_tests_wgisd = []
fps_tests_wgisd = []
coco_tests_wgrape = []
fps_tests_wgrape = []

lr=0.005
coco = None
metric_logger=[]
for backbone in backbones:
    # get the model using our helper function
    model = create_model(num_classes, backbone=backbone)
    # model = torch.load("weights/wgisd_frcnn.pth")

    # move model to the right device
    model.to(DEVICE)

    params = [p for p in model.parameters() if p.requires_grad]
    print(len(params))

    optimizer = torch.optim.SGD(params, lr=lr, momentum=0.9, weight_decay=lr*0.1)

    # and a learning rate scheduler which decreases the learning rate by
    # 10x every 3 epochs
    lr_scheduler = torch.optim.lr_scheduler.StepLR(
        optimizer,
        gamma=0.1,
        step_size=3
    )
    for epoch in range(EPOCHS):
        gc.collect()
        torch.cuda.empty_cache()
        # training for one epoch
        train_one_epoch(model, optimizer, data_loader_wgisd, DEVICE, epoch, 10)
        lr_scheduler.step()
        coco = evaluate(model, data_loader_test_wgisd, device=DEVICE)
        # evaluate on the test dataset

    img, target = dataset_test_wgisd[0]
    starter, ender = torch.cuda.Event(enable_timing=True), torch.cuda.Event(enable_timing=True)
    repetitions = 300
    timings=np.zeros((repetitions,1))
    #GPU-WARM-UP
    model.eval()
    with torch.no_grad():
        for _ in range(10):
            _ = model([img.to(DEVICE)])[0]
        # MEASURE PERFORMANCEì
        for rep in range(repetitions):
            starter.record()
            _ = model([img.to(DEVICE)])[0]
            ender.record()
            # WAIT FOR GPU SYNC
            torch.cuda.synchronize()
            curr_time = starter.elapsed_time(ender)
            timings[rep] = curr_time

    inference_time = np.sum(timings) / repetitions
    std_syn = np.std(timings)
    print(inference_time)

    fps_tests_wgisd.append(inference_time)
    coco_tests_wgisd.append(coco)

for backbone in backbones:
    # get the model using our helper function
    model = create_model(num_classes, backbone=backbone)
    # model = torch.load("weights/wgisd_frcnn.pth")

    # move model to the right device
    model.to(DEVICE)

    params = [p for p in model.parameters() if p.requires_grad]
    print(len(params))

    optimizer = torch.optim.SGD(params, lr=lr, momentum=0.9, weight_decay=lr*0.1)

    # and a learning rate scheduler which decreases the learning rate by
    # 10x every 3 epochs
    lr_scheduler = torch.optim.lr_scheduler.StepLR(
        optimizer,
        gamma=0.1,
        step_size=3
    )
    for epoch in range(EPOCHS):
        gc.collect()
        torch.cuda.empty_cache()
        # training for one epoch
        train_one_epoch(model, optimizer, data_loader_wgrape, DEVICE, epoch, 10)
        lr_scheduler.step()
        coco = evaluate(model, data_loader_test_wgrape, device=DEVICE)
        # evaluate on the test dataset

    img, target = dataset_test_wgrape[0]
    starter, ender = torch.cuda.Event(enable_timing=True), torch.cuda.Event(enable_timing=True)
    repetitions = 300
    timings=np.zeros((repetitions,1))
    #GPU-WARM-UP
    model.eval()
    with torch.no_grad():
        for _ in range(10):
            _ = model([img.to(DEVICE)])[0]
        # MEASURE PERFORMANCEì
        for rep in range(repetitions):
            starter.record()
            _ = model([img.to(DEVICE)])[0]
            ender.record()
            # WAIT FOR GPU SYNC
            torch.cuda.synchronize()
            curr_time = starter.elapsed_time(ender)
            timings[rep] = curr_time

    inference_time = np.sum(timings) / repetitions
    std_syn = np.std(timings)
    print(inference_time)

    fps_tests_wgrape.append(inference_time)
    coco_tests_wgrape.append(coco)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V2_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V2_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/mobilenet_v2-b0353104.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v2-b0353104.pth
# 100%|██████████| 13.6M/13.6M [00:00<00:00, 80.9MB/s]
# 170
# Epoch: [0]  [  0/240]  eta: 0:09:23  lr: 0.000026  loss: 1.5363 (1.5363)  loss_classifier: 0.7492 (0.7492)  loss_box_reg: 0.0187 (0.0187)  loss_objectness: 0.7051 (0.7051)  loss_rpn_box_reg: 0.0632 (0.0632)  time: 2.3497  data: 0.3272  max mem: 1995
# Epoch: [0]  [ 10/240]  eta: 0:02:05  lr: 0.000235  loss: 1.5566 (1.4975)  loss_classifier: 0.6571 (0.6233)  loss_box_reg: 0.0659 (0.0665)  loss_objectness: 0.7021 (0.7047)  loss_rpn_box_reg: 0.0900 (0.1030)  time: 0.5448  data: 0.1968  max mem: 2650
# Epoch: [0]  [ 20/240]  eta: 0:01:37  lr: 0.000444  loss: 1.2209 (1.3164)  loss_classifier: 0.3919 (0.4677)  loss_box_reg: 0.0775 (0.0852)  loss_objectness: 0.6772 (0.6697)  loss_rpn_box_reg: 0.0804 (0.0938)  time: 0.3469  data: 0.1699  max mem: 2651
# Epoch: [0]  [ 30/240]  eta: 0:01:22  lr: 0.000653  loss: 1.0361 (1.1996)  loss_classifier: 0.2847 (0.4104)  loss_box_reg: 0.1065 (0.0966)  loss_objectness: 0.5428 (0.6104)  loss_rpn_box_reg: 0.0652 (0.0822)  time: 0.3081  data: 0.1451  max mem: 2651
# Epoch: [0]  [ 40/240]  eta: 0:01:12  lr: 0.000862  loss: 0.9043 (1.1385)  loss_classifier: 0.2847 (0.3903)  loss_box_reg: 0.1504 (0.1197)  loss_objectness: 0.4305 (0.5500)  loss_rpn_box_reg: 0.0610 (0.0785)  time: 0.2739  data: 0.1156  max mem: 2733
# Epoch: [0]  [ 50/240]  eta: 0:01:05  lr: 0.001071  loss: 0.8688 (1.0810)  loss_classifier: 0.2906 (0.3697)  loss_box_reg: 0.2017 (0.1419)  loss_objectness: 0.2897 (0.4952)  loss_rpn_box_reg: 0.0629 (0.0742)  time: 0.2761  data: 0.1136  max mem: 2733
# Epoch: [0]  [ 60/240]  eta: 0:01:00  lr: 0.001280  loss: 0.8157 (1.0266)  loss_classifier: 0.2707 (0.3518)  loss_box_reg: 0.2063 (0.1567)  loss_objectness: 0.2449 (0.4479)  loss_rpn_box_reg: 0.0545 (0.0702)  time: 0.2929  data: 0.1318  max mem: 2733
# Epoch: [0]  [ 70/240]  eta: 0:00:57  lr: 0.001489  loss: 0.7778 (0.9890)  loss_classifier: 0.2526 (0.3394)  loss_box_reg: 0.2179 (0.1659)  loss_objectness: 0.1852 (0.4142)  loss_rpn_box_reg: 0.0589 (0.0695)  time: 0.3136  data: 0.1524  max mem: 2733
# Epoch: [0]  [ 80/240]  eta: 0:00:52  lr: 0.001698  loss: 0.7780 (0.9572)  loss_classifier: 0.2737 (0.3302)  loss_box_reg: 0.2210 (0.1774)  loss_objectness: 0.1617 (0.3826)  loss_rpn_box_reg: 0.0516 (0.0670)  time: 0.3014  data: 0.1405  max mem: 2733
# Epoch: [0]  [ 90/240]  eta: 0:00:48  lr: 0.001907  loss: 0.8199 (0.9500)  loss_classifier: 0.3126 (0.3300)  loss_box_reg: 0.3137 (0.1970)  loss_objectness: 0.1588 (0.3581)  loss_rpn_box_reg: 0.0488 (0.0648)  time: 0.2627  data: 0.1031  max mem: 2733
# Epoch: [0]  [100/240]  eta: 0:00:44  lr: 0.002116  loss: 0.8791 (0.9479)  loss_classifier: 0.3218 (0.3298)  loss_box_reg: 0.3228 (0.2154)  loss_objectness: 0.1627 (0.3391)  loss_rpn_box_reg: 0.0488 (0.0636)  time: 0.2652  data: 0.1045  max mem: 2733
# Epoch: [0]  [110/240]  eta: 0:00:41  lr: 0.002325  loss: 0.8143 (0.9408)  loss_classifier: 0.2996 (0.3272)  loss_box_reg: 0.3156 (0.2246)  loss_objectness: 0.1606 (0.3252)  loss_rpn_box_reg: 0.0522 (0.0638)  time: 0.3014  data: 0.1384  max mem: 2845
# Epoch: [0]  [120/240]  eta: 0:00:37  lr: 0.002534  loss: 0.7976 (0.9291)  loss_classifier: 0.2815 (0.3244)  loss_box_reg: 0.3283 (0.2344)  loss_objectness: 0.1346 (0.3084)  loss_rpn_box_reg: 0.0463 (0.0619)  time: 0.3083  data: 0.1447  max mem: 2845
# Epoch: [0]  [130/240]  eta: 0:00:34  lr: 0.002743  loss: 0.7510 (0.9146)  loss_classifier: 0.2740 (0.3202)  loss_box_reg: 0.3179 (0.2389)  loss_objectness: 0.1219 (0.2941)  loss_rpn_box_reg: 0.0418 (0.0613)  time: 0.2810  data: 0.1168  max mem: 2850
# Epoch: [0]  [140/240]  eta: 0:00:30  lr: 0.002952  loss: 0.6607 (0.8983)  loss_classifier: 0.2494 (0.3154)  loss_box_reg: 0.2512 (0.2420)  loss_objectness: 0.1125 (0.2806)  loss_rpn_box_reg: 0.0418 (0.0603)  time: 0.2689  data: 0.1102  max mem: 2850
# Epoch: [0]  [150/240]  eta: 0:00:27  lr: 0.003161  loss: 0.7912 (0.9033)  loss_classifier: 0.2884 (0.3169)  loss_box_reg: 0.3283 (0.2551)  loss_objectness: 0.1125 (0.2707)  loss_rpn_box_reg: 0.0507 (0.0606)  time: 0.2674  data: 0.1103  max mem: 2850
# Epoch: [0]  [160/240]  eta: 0:00:24  lr: 0.003370  loss: 0.8423 (0.8957)  loss_classifier: 0.3047 (0.3139)  loss_box_reg: 0.3764 (0.2622)  loss_objectness: 0.1125 (0.2597)  loss_rpn_box_reg: 0.0547 (0.0599)  time: 0.2789  data: 0.1188  max mem: 2850
# Epoch: [0]  [170/240]  eta: 0:00:21  lr: 0.003579  loss: 0.7076 (0.8876)  loss_classifier: 0.2550 (0.3110)  loss_box_reg: 0.3213 (0.2660)  loss_objectness: 0.0819 (0.2501)  loss_rpn_box_reg: 0.0568 (0.0605)  time: 0.3169  data: 0.1580  max mem: 2850
# Epoch: [0]  [180/240]  eta: 0:00:18  lr: 0.003788  loss: 0.6725 (0.8755)  loss_classifier: 0.2458 (0.3076)  loss_box_reg: 0.2905 (0.2671)  loss_objectness: 0.0819 (0.2407)  loss_rpn_box_reg: 0.0536 (0.0602)  time: 0.3030  data: 0.1464  max mem: 2850
# Epoch: [0]  [190/240]  eta: 0:00:15  lr: 0.003997  loss: 0.6252 (0.8697)  loss_classifier: 0.2452 (0.3061)  loss_box_reg: 0.2691 (0.2705)  loss_objectness: 0.0880 (0.2336)  loss_rpn_box_reg: 0.0488 (0.0595)  time: 0.2725  data: 0.1169  max mem: 2850
# Epoch: [0]  [200/240]  eta: 0:00:12  lr: 0.004206  loss: 0.7835 (0.8714)  loss_classifier: 0.2825 (0.3074)  loss_box_reg: 0.3501 (0.2779)  loss_objectness: 0.1004 (0.2272)  loss_rpn_box_reg: 0.0517 (0.0590)  time: 0.2862  data: 0.1279  max mem: 2850
# Epoch: [0]  [210/240]  eta: 0:00:09  lr: 0.004415  loss: 0.7391 (0.8640)  loss_classifier: 0.2810 (0.3056)  loss_box_reg: 0.3501 (0.2796)  loss_objectness: 0.0898 (0.2205)  loss_rpn_box_reg: 0.0419 (0.0583)  time: 0.2888  data: 0.1298  max mem: 2850
# Epoch: [0]  [220/240]  eta: 0:00:06  lr: 0.004624  loss: 0.7391 (0.8635)  loss_classifier: 0.2777 (0.3052)  loss_box_reg: 0.3305 (0.2851)  loss_objectness: 0.0894 (0.2151)  loss_rpn_box_reg: 0.0451 (0.0581)  time: 0.2894  data: 0.1295  max mem: 2850
# Epoch: [0]  [230/240]  eta: 0:00:03  lr: 0.004833  loss: 0.8227 (0.8617)  loss_classifier: 0.2869 (0.3036)  loss_box_reg: 0.3854 (0.2912)  loss_objectness: 0.0847 (0.2091)  loss_rpn_box_reg: 0.0547 (0.0577)  time: 0.2802  data: 0.1188  max mem: 2850
# Epoch: [0]  [239/240]  eta: 0:00:00  lr: 0.005000  loss: 0.6867 (0.8521)  loss_classifier: 0.2223 (0.2998)  loss_box_reg: 0.3260 (0.2916)  loss_objectness: 0.0674 (0.2036)  loss_rpn_box_reg: 0.0408 (0.0572)  time: 0.2698  data: 0.1102  max mem: 2850
# Epoch: [0] Total time: 0:01:11 (0.2990 s / it)
# creating index...
# index created!
# Test:  [ 0/60]  eta: 0:00:17  model_time: 0.0855 (0.0855)  evaluator_time: 0.0809 (0.0809)  time: 0.2854  data: 0.1145  max mem: 2850
# Test:  [59/60]  eta: 0:00:00  model_time: 0.0479 (0.0585)  evaluator_time: 0.0304 (0.0355)  time: 0.1502  data: 0.0647  max mem: 2850
# Test: Total time: 0:00:09 (0.1666 s / it)
# Averaged stats: model_time: 0.0479 (0.0585)  evaluator_time: 0.0304 (0.0355)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.042
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.188
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.056
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.014
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.071
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.206
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.100
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.254
# Epoch: [1]  [  0/240]  eta: 0:00:56  lr: 0.005000  loss: 0.6758 (0.6758)  loss_classifier: 0.2184 (0.2184)  loss_box_reg: 0.2879 (0.2879)  loss_objectness: 0.0951 (0.0951)  loss_rpn_box_reg: 0.0744 (0.0744)  time: 0.2356  data: 0.0801  max mem: 2850
# Epoch: [1]  [ 10/240]  eta: 0:01:07  lr: 0.005000  loss: 0.8277 (0.8728)  loss_classifier: 0.2536 (0.2717)  loss_box_reg: 0.4471 (0.4456)  loss_objectness: 0.0951 (0.0960)  loss_rpn_box_reg: 0.0529 (0.0595)  time: 0.2944  data: 0.1324  max mem: 2850
# Epoch: [1]  [ 20/240]  eta: 0:01:07  lr: 0.005000  loss: 0.8324 (0.8476)  loss_classifier: 0.2656 (0.2761)  loss_box_reg: 0.4216 (0.4118)  loss_objectness: 0.0860 (0.0966)  loss_rpn_box_reg: 0.0588 (0.0630)  time: 0.3119  data: 0.1458  max mem: 2850
# Epoch: [1]  [ 30/240]  eta: 0:01:02  lr: 0.005000  loss: 0.7476 (0.8258)  loss_classifier: 0.2394 (0.2654)  loss_box_reg: 0.3240 (0.3946)  loss_objectness: 0.0961 (0.0989)  loss_rpn_box_reg: 0.0590 (0.0669)  time: 0.2992  data: 0.1318  max mem: 2850
# Epoch: [1]  [ 40/240]  eta: 0:00:58  lr: 0.005000  loss: 0.6931 (0.8085)  loss_classifier: 0.2317 (0.2573)  loss_box_reg: 0.3073 (0.3920)  loss_objectness: 0.0927 (0.0959)  loss_rpn_box_reg: 0.0536 (0.0632)  time: 0.2734  data: 0.1121  max mem: 2850
# Epoch: [1]  [ 50/240]  eta: 0:00:54  lr: 0.005000  loss: 0.7123 (0.8032)  loss_classifier: 0.2465 (0.2557)  loss_box_reg: 0.3721 (0.3915)  loss_objectness: 0.0823 (0.0948)  loss_rpn_box_reg: 0.0455 (0.0612)  time: 0.2707  data: 0.1097  max mem: 2850
# Epoch: [1]  [ 60/240]  eta: 0:00:51  lr: 0.005000  loss: 0.7455 (0.7961)  loss_classifier: 0.2445 (0.2527)  loss_box_reg: 0.3801 (0.3913)  loss_objectness: 0.0781 (0.0938)  loss_rpn_box_reg: 0.0450 (0.0583)  time: 0.2836  data: 0.1194  max mem: 2850
# Epoch: [1]  [ 70/240]  eta: 0:00:50  lr: 0.005000  loss: 0.7010 (0.8008)  loss_classifier: 0.2445 (0.2541)  loss_box_reg: 0.3847 (0.4000)  loss_objectness: 0.0704 (0.0910)  loss_rpn_box_reg: 0.0370 (0.0557)  time: 0.3197  data: 0.1536  max mem: 2850
# Epoch: [1]  [ 80/240]  eta: 0:00:46  lr: 0.005000  loss: 0.8191 (0.8119)  loss_classifier: 0.2604 (0.2574)  loss_box_reg: 0.4680 (0.4099)  loss_objectness: 0.0662 (0.0908)  loss_rpn_box_reg: 0.0390 (0.0539)  time: 0.3080  data: 0.1405  max mem: 2850
# Epoch: [1]  [ 90/240]  eta: 0:00:43  lr: 0.005000  loss: 0.8329 (0.8271)  loss_classifier: 0.2605 (0.2605)  loss_box_reg: 0.4775 (0.4239)  loss_objectness: 0.0700 (0.0897)  loss_rpn_box_reg: 0.0399 (0.0529)  time: 0.2694  data: 0.1034  max mem: 2850
# Epoch: [1]  [100/240]  eta: 0:00:40  lr: 0.005000  loss: 0.8789 (0.8336)  loss_classifier: 0.2605 (0.2605)  loss_box_reg: 0.5318 (0.4330)  loss_objectness: 0.0701 (0.0887)  loss_rpn_box_reg: 0.0380 (0.0515)  time: 0.2715  data: 0.1048  max mem: 2850
# Epoch: [1]  [110/240]  eta: 0:00:37  lr: 0.005000  loss: 0.8462 (0.8357)  loss_classifier: 0.2518 (0.2612)  loss_box_reg: 0.4992 (0.4380)  loss_objectness: 0.0631 (0.0864)  loss_rpn_box_reg: 0.0371 (0.0501)  time: 0.2754  data: 0.1080  max mem: 2850
# Epoch: [1]  [120/240]  eta: 0:00:34  lr: 0.005000  loss: 0.7897 (0.8249)  loss_classifier: 0.2446 (0.2572)  loss_box_reg: 0.4429 (0.4352)  loss_objectness: 0.0540 (0.0839)  loss_rpn_box_reg: 0.0337 (0.0487)  time: 0.2968  data: 0.1308  max mem: 2850
# Epoch: [1]  [130/240]  eta: 0:00:31  lr: 0.005000  loss: 0.7164 (0.8272)  loss_classifier: 0.2190 (0.2576)  loss_box_reg: 0.4089 (0.4389)  loss_objectness: 0.0596 (0.0827)  loss_rpn_box_reg: 0.0311 (0.0479)  time: 0.3035  data: 0.1389  max mem: 2850
# Epoch: [1]  [140/240]  eta: 0:00:28  lr: 0.005000  loss: 0.7510 (0.8309)  loss_classifier: 0.2431 (0.2576)  loss_box_reg: 0.4565 (0.4438)  loss_objectness: 0.0598 (0.0821)  loss_rpn_box_reg: 0.0330 (0.0474)  time: 0.2825  data: 0.1175  max mem: 2850
# Epoch: [1]  [150/240]  eta: 0:00:25  lr: 0.005000  loss: 0.7753 (0.8295)  loss_classifier: 0.2611 (0.2589)  loss_box_reg: 0.4228 (0.4420)  loss_objectness: 0.0603 (0.0815)  loss_rpn_box_reg: 0.0361 (0.0470)  time: 0.2723  data: 0.1086  max mem: 2850
# Epoch: [1]  [160/240]  eta: 0:00:23  lr: 0.005000  loss: 0.7426 (0.8236)  loss_classifier: 0.2387 (0.2574)  loss_box_reg: 0.3630 (0.4381)  loss_objectness: 0.0639 (0.0816)  loss_rpn_box_reg: 0.0361 (0.0465)  time: 0.2895  data: 0.1266  max mem: 2850
# Epoch: [1]  [170/240]  eta: 0:00:20  lr: 0.005000  loss: 0.6816 (0.8185)  loss_classifier: 0.1979 (0.2544)  loss_box_reg: 0.3515 (0.4382)  loss_objectness: 0.0516 (0.0802)  loss_rpn_box_reg: 0.0328 (0.0458)  time: 0.3198  data: 0.1537  max mem: 2850
# Epoch: [1]  [180/240]  eta: 0:00:17  lr: 0.005000  loss: 0.6850 (0.8130)  loss_classifier: 0.1959 (0.2521)  loss_box_reg: 0.3973 (0.4371)  loss_objectness: 0.0507 (0.0787)  loss_rpn_box_reg: 0.0328 (0.0452)  time: 0.3249  data: 0.1577  max mem: 2850
# Epoch: [1]  [190/240]  eta: 0:00:14  lr: 0.005000  loss: 0.7032 (0.8150)  loss_classifier: 0.2191 (0.2524)  loss_box_reg: 0.4254 (0.4402)  loss_objectness: 0.0464 (0.0774)  loss_rpn_box_reg: 0.0348 (0.0449)  time: 0.3109  data: 0.1438  max mem: 2850
# Epoch: [1]  [200/240]  eta: 0:00:11  lr: 0.005000  loss: 0.7531 (0.8149)  loss_classifier: 0.2283 (0.2523)  loss_box_reg: 0.4322 (0.4413)  loss_objectness: 0.0485 (0.0765)  loss_rpn_box_reg: 0.0401 (0.0449)  time: 0.2805  data: 0.1119  max mem: 2850
# Epoch: [1]  [210/240]  eta: 0:00:08  lr: 0.005000  loss: 0.6775 (0.8090)  loss_classifier: 0.2118 (0.2500)  loss_box_reg: 0.4088 (0.4392)  loss_objectness: 0.0485 (0.0754)  loss_rpn_box_reg: 0.0392 (0.0443)  time: 0.2900  data: 0.1241  max mem: 2850
# Epoch: [1]  [220/240]  eta: 0:00:05  lr: 0.005000  loss: 0.6775 (0.8091)  loss_classifier: 0.1942 (0.2489)  loss_box_reg: 0.3916 (0.4410)  loss_objectness: 0.0531 (0.0749)  loss_rpn_box_reg: 0.0391 (0.0443)  time: 0.3006  data: 0.1341  max mem: 2850
# Epoch: [1]  [230/240]  eta: 0:00:02  lr: 0.005000  loss: 0.7078 (0.8071)  loss_classifier: 0.2126 (0.2481)  loss_box_reg: 0.4192 (0.4407)  loss_objectness: 0.0518 (0.0739)  loss_rpn_box_reg: 0.0399 (0.0445)  time: 0.2803  data: 0.1118  max mem: 2850
# Epoch: [1]  [239/240]  eta: 0:00:00  lr: 0.005000  loss: 0.7078 (0.8075)  loss_classifier: 0.2565 (0.2485)  loss_box_reg: 0.3932 (0.4410)  loss_objectness: 0.0477 (0.0736)  loss_rpn_box_reg: 0.0399 (0.0443)  time: 0.2723  data: 0.1074  max mem: 2850
# Epoch: [1] Total time: 0:01:09 (0.2914 s / it)
# creating index...
# index created!
# Test:  [ 0/60]  eta: 0:00:12  model_time: 0.0833 (0.0833)  evaluator_time: 0.0481 (0.0481)  time: 0.2061  data: 0.0706  max mem: 2850
# Test:  [59/60]  eta: 0:00:00  model_time: 0.0482 (0.0523)  evaluator_time: 0.0276 (0.0295)  time: 0.1449  data: 0.0627  max mem: 2850
# Test: Total time: 0:00:08 (0.1475 s / it)
# Averaged stats: model_time: 0.0482 (0.0523)  evaluator_time: 0.0276 (0.0295)
# Accumulating evaluation results...
# DONE (t=0.08s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.163
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.514
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.061
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.061
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.210
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.031
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.182
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.326
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.173
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.396
# Epoch: [2]  [  0/240]  eta: 0:01:04  lr: 0.005000  loss: 0.9963 (0.9963)  loss_classifier: 0.3068 (0.3068)  loss_box_reg: 0.5852 (0.5852)  loss_objectness: 0.0546 (0.0546)  loss_rpn_box_reg: 0.0495 (0.0495)  time: 0.2699  data: 0.1051  max mem: 2850
# Epoch: [2]  [ 10/240]  eta: 0:01:12  lr: 0.005000  loss: 0.7537 (0.7863)  loss_classifier: 0.2189 (0.2317)  loss_box_reg: 0.4657 (0.4635)  loss_objectness: 0.0458 (0.0522)  loss_rpn_box_reg: 0.0398 (0.0389)  time: 0.3143  data: 0.1507  max mem: 2850
# Epoch: [2]  [ 20/240]  eta: 0:01:04  lr: 0.005000  loss: 0.6591 (0.7106)  loss_classifier: 0.1819 (0.2074)  loss_box_reg: 0.3759 (0.4211)  loss_objectness: 0.0397 (0.0463)  loss_rpn_box_reg: 0.0364 (0.0359)  time: 0.2932  data: 0.1303  max mem: 2850
# Epoch: [2]  [ 30/240]  eta: 0:01:01  lr: 0.005000  loss: 0.8163 (0.7647)  loss_classifier: 0.2348 (0.2221)  loss_box_reg: 0.4546 (0.4487)  loss_objectness: 0.0533 (0.0536)  loss_rpn_box_reg: 0.0367 (0.0402)  time: 0.2797  data: 0.1185  max mem: 2850
# Epoch: [2]  [ 40/240]  eta: 0:00:58  lr: 0.005000  loss: 0.8280 (0.7781)  loss_classifier: 0.2490 (0.2259)  loss_box_reg: 0.4728 (0.4557)  loss_objectness: 0.0579 (0.0553)  loss_rpn_box_reg: 0.0478 (0.0412)  time: 0.2886  data: 0.1267  max mem: 2850
# Epoch: [2]  [ 50/240]  eta: 0:00:54  lr: 0.005000  loss: 0.7318 (0.7700)  loss_classifier: 0.2299 (0.2263)  loss_box_reg: 0.4371 (0.4501)  loss_objectness: 0.0467 (0.0544)  loss_rpn_box_reg: 0.0295 (0.0392)  time: 0.2813  data: 0.1155  max mem: 2850
# Epoch: [2]  [ 60/240]  eta: 0:00:53  lr: 0.005000  loss: 0.7095 (0.7716)  loss_classifier: 0.2102 (0.2272)  loss_box_reg: 0.4261 (0.4484)  loss_objectness: 0.0562 (0.0574)  loss_rpn_box_reg: 0.0276 (0.0386)  time: 0.3030  data: 0.1363  max mem: 2850
# Epoch: [2]  [ 70/240]  eta: 0:00:49  lr: 0.005000  loss: 0.7043 (0.7735)  loss_classifier: 0.2008 (0.2264)  loss_box_reg: 0.4381 (0.4512)  loss_objectness: 0.0632 (0.0580)  loss_rpn_box_reg: 0.0308 (0.0379)  time: 0.3041  data: 0.1408  max mem: 2850
# Epoch: [2]  [ 80/240]  eta: 0:00:46  lr: 0.005000  loss: 0.7002 (0.7773)  loss_classifier: 0.2021 (0.2282)  loss_box_reg: 0.4370 (0.4525)  loss_objectness: 0.0578 (0.0589)  loss_rpn_box_reg: 0.0317 (0.0377)  time: 0.2679  data: 0.1071  max mem: 2850
# Epoch: [2]  [ 90/240]  eta: 0:00:43  lr: 0.005000  loss: 0.6998 (0.7655)  loss_classifier: 0.1985 (0.2240)  loss_box_reg: 0.4080 (0.4480)  loss_objectness: 0.0447 (0.0573)  loss_rpn_box_reg: 0.0295 (0.0363)  time: 0.2665  data: 0.1040  max mem: 2850
# Epoch: [2]  [100/240]  eta: 0:00:40  lr: 0.005000  loss: 0.7034 (0.7640)  loss_classifier: 0.2004 (0.2229)  loss_box_reg: 0.4301 (0.4486)  loss_objectness: 0.0432 (0.0566)  loss_rpn_box_reg: 0.0248 (0.0358)  time: 0.2846  data: 0.1177  max mem: 2850
# Epoch: [2]  [110/240]  eta: 0:00:37  lr: 0.005000  loss: 0.7325 (0.7666)  loss_classifier: 0.2136 (0.2239)  loss_box_reg: 0.4545 (0.4497)  loss_objectness: 0.0407 (0.0570)  loss_rpn_box_reg: 0.0284 (0.0361)  time: 0.3178  data: 0.1471  max mem: 2850
# Epoch: [2]  [120/240]  eta: 0:00:35  lr: 0.005000  loss: 0.7196 (0.7651)  loss_classifier: 0.2190 (0.2238)  loss_box_reg: 0.4261 (0.4487)  loss_objectness: 0.0407 (0.0565)  loss_rpn_box_reg: 0.0311 (0.0360)  time: 0.3138  data: 0.1473  max mem: 2850
# Epoch: [2]  [130/240]  eta: 0:00:31  lr: 0.005000  loss: 0.6958 (0.7705)  loss_classifier: 0.2156 (0.2246)  loss_box_reg: 0.4260 (0.4488)  loss_objectness: 0.0465 (0.0576)  loss_rpn_box_reg: 0.0531 (0.0395)  time: 0.2782  data: 0.1107  max mem: 2850
# Epoch: [2]  [140/240]  eta: 0:00:28  lr: 0.005000  loss: 0.6869 (0.7707)  loss_classifier: 0.2156 (0.2243)  loss_box_reg: 0.4117 (0.4497)  loss_objectness: 0.0464 (0.0567)  loss_rpn_box_reg: 0.0560 (0.0399)  time: 0.2797  data: 0.1074  max mem: 2850
# Epoch: [2]  [150/240]  eta: 0:00:26  lr: 0.005000  loss: 0.6846 (0.7628)  loss_classifier: 0.2095 (0.2226)  loss_box_reg: 0.4117 (0.4447)  loss_objectness: 0.0391 (0.0563)  loss_rpn_box_reg: 0.0329 (0.0393)  time: 0.2987  data: 0.1290  max mem: 2850
# Epoch: [2]  [160/240]  eta: 0:00:23  lr: 0.005000  loss: 0.6475 (0.7607)  loss_classifier: 0.2092 (0.2219)  loss_box_reg: 0.4295 (0.4443)  loss_objectness: 0.0432 (0.0557)  loss_rpn_box_reg: 0.0284 (0.0388)  time: 0.3147  data: 0.1487  max mem: 2850
# Epoch: [2]  [170/240]  eta: 0:00:20  lr: 0.005000  loss: 0.6723 (0.7573)  loss_classifier: 0.2043 (0.2212)  loss_box_reg: 0.4133 (0.4419)  loss_objectness: 0.0444 (0.0557)  loss_rpn_box_reg: 0.0284 (0.0384)  time: 0.2938  data: 0.1329  max mem: 2850
# Epoch: [2]  [180/240]  eta: 0:00:17  lr: 0.005000  loss: 0.8076 (0.7603)  loss_classifier: 0.2062 (0.2214)  loss_box_reg: 0.4640 (0.4435)  loss_objectness: 0.0546 (0.0567)  loss_rpn_box_reg: 0.0319 (0.0387)  time: 0.2823  data: 0.1214  max mem: 2850
# Epoch: [2]  [190/240]  eta: 0:00:14  lr: 0.005000  loss: 0.8076 (0.7584)  loss_classifier: 0.2062 (0.2208)  loss_box_reg: 0.4640 (0.4423)  loss_objectness: 0.0542 (0.0567)  loss_rpn_box_reg: 0.0339 (0.0386)  time: 0.2831  data: 0.1219  max mem: 2850
# Epoch: [2]  [200/240]  eta: 0:00:11  lr: 0.005000  loss: 0.7921 (0.7614)  loss_classifier: 0.2293 (0.2215)  loss_box_reg: 0.4474 (0.4456)  loss_objectness: 0.0460 (0.0560)  loss_rpn_box_reg: 0.0308 (0.0383)  time: 0.2898  data: 0.1271  max mem: 2850
# Epoch: [2]  [210/240]  eta: 0:00:08  lr: 0.005000  loss: 0.8043 (0.7681)  loss_classifier: 0.2594 (0.2230)  loss_box_reg: 0.5146 (0.4504)  loss_objectness: 0.0494 (0.0564)  loss_rpn_box_reg: 0.0330 (0.0383)  time: 0.3095  data: 0.1429  max mem: 2850
# Epoch: [2]  [220/240]  eta: 0:00:05  lr: 0.005000  loss: 0.7813 (0.7649)  loss_classifier: 0.2137 (0.2218)  loss_box_reg: 0.4788 (0.4495)  loss_objectness: 0.0417 (0.0557)  loss_rpn_box_reg: 0.0317 (0.0379)  time: 0.2875  data: 0.1222  max mem: 2850
# Epoch: [2]  [230/240]  eta: 0:00:02  lr: 0.005000  loss: 0.6399 (0.7619)  loss_classifier: 0.1994 (0.2211)  loss_box_reg: 0.3976 (0.4480)  loss_objectness: 0.0417 (0.0552)  loss_rpn_box_reg: 0.0292 (0.0376)  time: 0.2778  data: 0.1112  max mem: 2850
# Epoch: [2]  [239/240]  eta: 0:00:00  lr: 0.005000  loss: 0.7431 (0.7659)  loss_classifier: 0.2136 (0.2218)  loss_box_reg: 0.4401 (0.4516)  loss_objectness: 0.0438 (0.0550)  loss_rpn_box_reg: 0.0300 (0.0375)  time: 0.2877  data: 0.1209  max mem: 2850
# Epoch: [2] Total time: 0:01:09 (0.2913 s / it)
# creating index...
# index created!
# Test:  [ 0/60]  eta: 0:00:12  model_time: 0.0843 (0.0843)  evaluator_time: 0.0510 (0.0510)  time: 0.2124  data: 0.0732  max mem: 2850
# Test:  [59/60]  eta: 0:00:00  model_time: 0.0473 (0.0528)  evaluator_time: 0.0284 (0.0313)  time: 0.1535  data: 0.0673  max mem: 2850
# Test: Total time: 0:00:09 (0.1515 s / it)
# Averaged stats: model_time: 0.0473 (0.0528)  evaluator_time: 0.0284 (0.0313)
# Accumulating evaluation results...
# DONE (t=0.09s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.219
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.597
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.103
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.098
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.276
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.225
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.365
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.224
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.430
# Epoch: [3]  [  0/240]  eta: 0:01:13  lr: 0.000500  loss: 0.7285 (0.7285)  loss_classifier: 0.2232 (0.2232)  loss_box_reg: 0.4775 (0.4775)  loss_objectness: 0.0152 (0.0152)  loss_rpn_box_reg: 0.0127 (0.0127)  time: 0.3046  data: 0.1464  max mem: 2850
# Epoch: [3]  [ 10/240]  eta: 0:01:18  lr: 0.000500  loss: 0.7285 (0.7128)  loss_classifier: 0.2024 (0.2187)  loss_box_reg: 0.4371 (0.4151)  loss_objectness: 0.0382 (0.0465)  loss_rpn_box_reg: 0.0260 (0.0325)  time: 0.3430  data: 0.1805  max mem: 2850
# Epoch: [3]  [ 20/240]  eta: 0:01:08  lr: 0.000500  loss: 0.7374 (0.7201)  loss_classifier: 0.1983 (0.2098)  loss_box_reg: 0.4371 (0.4337)  loss_objectness: 0.0392 (0.0469)  loss_rpn_box_reg: 0.0242 (0.0298)  time: 0.3128  data: 0.1509  max mem: 2850
# Epoch: [3]  [ 30/240]  eta: 0:01:02  lr: 0.000500  loss: 0.7584 (0.7555)  loss_classifier: 0.1983 (0.2231)  loss_box_reg: 0.4562 (0.4472)  loss_objectness: 0.0463 (0.0543)  loss_rpn_box_reg: 0.0226 (0.0309)  time: 0.2737  data: 0.1112  max mem: 2850
# Epoch: [3]  [ 40/240]  eta: 0:00:57  lr: 0.000500  loss: 0.7586 (0.7547)  loss_classifier: 0.2074 (0.2194)  loss_box_reg: 0.4562 (0.4524)  loss_objectness: 0.0456 (0.0527)  loss_rpn_box_reg: 0.0261 (0.0301)  time: 0.2632  data: 0.1017  max mem: 2850
# Epoch: [3]  [ 50/240]  eta: 0:00:54  lr: 0.000500  loss: 0.7128 (0.7340)  loss_classifier: 0.2039 (0.2120)  loss_box_reg: 0.4347 (0.4423)  loss_objectness: 0.0411 (0.0503)  loss_rpn_box_reg: 0.0257 (0.0294)  time: 0.2713  data: 0.1071  max mem: 2850
# Epoch: [3]  [ 60/240]  eta: 0:00:52  lr: 0.000500  loss: 0.8755 (0.7637)  loss_classifier: 0.2253 (0.2196)  loss_box_reg: 0.5223 (0.4611)  loss_objectness: 0.0482 (0.0525)  loss_rpn_box_reg: 0.0265 (0.0305)  time: 0.3052  data: 0.1356  max mem: 2850
# Epoch: [3]  [ 70/240]  eta: 0:00:50  lr: 0.000500  loss: 0.6959 (0.7502)  loss_classifier: 0.1975 (0.2145)  loss_box_reg: 0.4491 (0.4553)  loss_objectness: 0.0463 (0.0509)  loss_rpn_box_reg: 0.0256 (0.0294)  time: 0.3117  data: 0.1450  max mem: 2850
# Epoch: [3]  [ 80/240]  eta: 0:00:47  lr: 0.000500  loss: 0.6864 (0.7588)  loss_classifier: 0.1971 (0.2166)  loss_box_reg: 0.4401 (0.4612)  loss_objectness: 0.0454 (0.0515)  loss_rpn_box_reg: 0.0229 (0.0295)  time: 0.3059  data: 0.1405  max mem: 2850
# Epoch: [3]  [ 90/240]  eta: 0:00:44  lr: 0.000500  loss: 0.7125 (0.7505)  loss_classifier: 0.2042 (0.2138)  loss_box_reg: 0.4337 (0.4569)  loss_objectness: 0.0454 (0.0508)  loss_rpn_box_reg: 0.0233 (0.0290)  time: 0.2938  data: 0.1285  max mem: 2850
# Epoch: [3]  [100/240]  eta: 0:00:41  lr: 0.000500  loss: 0.6429 (0.7423)  loss_classifier: 0.1719 (0.2103)  loss_box_reg: 0.4220 (0.4528)  loss_objectness: 0.0410 (0.0504)  loss_rpn_box_reg: 0.0202 (0.0287)  time: 0.2939  data: 0.1312  max mem: 2850
# Epoch: [3]  [110/240]  eta: 0:00:38  lr: 0.000500  loss: 0.7502 (0.7375)  loss_classifier: 0.1908 (0.2099)  loss_box_reg: 0.4397 (0.4499)  loss_objectness: 0.0401 (0.0497)  loss_rpn_box_reg: 0.0172 (0.0280)  time: 0.3134  data: 0.1485  max mem: 2850
# Epoch: [3]  [120/240]  eta: 0:00:35  lr: 0.000500  loss: 0.7242 (0.7344)  loss_classifier: 0.2005 (0.2093)  loss_box_reg: 0.4448 (0.4498)  loss_objectness: 0.0280 (0.0480)  loss_rpn_box_reg: 0.0140 (0.0273)  time: 0.2973  data: 0.1296  max mem: 2850
# Epoch: [3]  [130/240]  eta: 0:00:32  lr: 0.000500  loss: 0.7530 (0.7474)  loss_classifier: 0.2139 (0.2128)  loss_box_reg: 0.5108 (0.4575)  loss_objectness: 0.0422 (0.0493)  loss_rpn_box_reg: 0.0264 (0.0278)  time: 0.2683  data: 0.1022  max mem: 2850
# Epoch: [3]  [140/240]  eta: 0:00:29  lr: 0.000500  loss: 0.8157 (0.7500)  loss_classifier: 0.2167 (0.2134)  loss_box_reg: 0.5307 (0.4597)  loss_objectness: 0.0539 (0.0492)  loss_rpn_box_reg: 0.0264 (0.0276)  time: 0.2734  data: 0.1091  max mem: 2850
# Epoch: [3]  [150/240]  eta: 0:00:26  lr: 0.000500  loss: 0.7432 (0.7526)  loss_classifier: 0.2061 (0.2138)  loss_box_reg: 0.4774 (0.4616)  loss_objectness: 0.0332 (0.0494)  loss_rpn_box_reg: 0.0249 (0.0277)  time: 0.3051  data: 0.1395  max mem: 2850
# Epoch: [3]  [160/240]  eta: 0:00:23  lr: 0.000500  loss: 0.6929 (0.7526)  loss_classifier: 0.1964 (0.2141)  loss_box_reg: 0.4505 (0.4614)  loss_objectness: 0.0455 (0.0496)  loss_rpn_box_reg: 0.0222 (0.0276)  time: 0.3144  data: 0.1485  max mem: 2850
# Epoch: [3]  [170/240]  eta: 0:00:20  lr: 0.000500  loss: 0.6862 (0.7489)  loss_classifier: 0.1943 (0.2132)  loss_box_reg: 0.4313 (0.4589)  loss_objectness: 0.0455 (0.0495)  loss_rpn_box_reg: 0.0221 (0.0272)  time: 0.2967  data: 0.1347  max mem: 2850
# Epoch: [3]  [180/240]  eta: 0:00:17  lr: 0.000500  loss: 0.6616 (0.7458)  loss_classifier: 0.1851 (0.2124)  loss_box_reg: 0.4036 (0.4574)  loss_objectness: 0.0340 (0.0488)  loss_rpn_box_reg: 0.0217 (0.0272)  time: 0.2858  data: 0.1266  max mem: 2850
# Epoch: [3]  [190/240]  eta: 0:00:14  lr: 0.000500  loss: 0.6982 (0.7453)  loss_classifier: 0.1842 (0.2122)  loss_box_reg: 0.4657 (0.4577)  loss_objectness: 0.0353 (0.0483)  loss_rpn_box_reg: 0.0212 (0.0271)  time: 0.2883  data: 0.1250  max mem: 2850
# Epoch: [3]  [200/240]  eta: 0:00:11  lr: 0.000500  loss: 0.7198 (0.7429)  loss_classifier: 0.1951 (0.2116)  loss_box_reg: 0.4657 (0.4568)  loss_objectness: 0.0357 (0.0479)  loss_rpn_box_reg: 0.0206 (0.0267)  time: 0.3102  data: 0.1430  max mem: 2850
# Epoch: [3]  [210/240]  eta: 0:00:08  lr: 0.000500  loss: 0.7770 (0.7504)  loss_classifier: 0.2147 (0.2133)  loss_box_reg: 0.5278 (0.4621)  loss_objectness: 0.0403 (0.0481)  loss_rpn_box_reg: 0.0226 (0.0270)  time: 0.3141  data: 0.1479  max mem: 2850
# Epoch: [3]  [220/240]  eta: 0:00:05  lr: 0.000500  loss: 0.8256 (0.7515)  loss_classifier: 0.2346 (0.2136)  loss_box_reg: 0.5252 (0.4624)  loss_objectness: 0.0440 (0.0483)  loss_rpn_box_reg: 0.0266 (0.0272)  time: 0.2715  data: 0.1085  max mem: 2850
# Epoch: [3]  [230/240]  eta: 0:00:02  lr: 0.000500  loss: 0.7029 (0.7493)  loss_classifier: 0.1912 (0.2128)  loss_box_reg: 0.4546 (0.4609)  loss_objectness: 0.0349 (0.0485)  loss_rpn_box_reg: 0.0211 (0.0271)  time: 0.2678  data: 0.1097  max mem: 2850
# Epoch: [3]  [239/240]  eta: 0:00:00  lr: 0.000500  loss: 0.7697 (0.7555)  loss_classifier: 0.2059 (0.2142)  loss_box_reg: 0.4605 (0.4649)  loss_objectness: 0.0431 (0.0489)  loss_rpn_box_reg: 0.0254 (0.0275)  time: 0.2743  data: 0.1137  max mem: 2850
# Epoch: [3] Total time: 0:01:10 (0.2928 s / it)
# creating index...
# index created!
# Test:  [ 0/60]  eta: 0:00:12  model_time: 0.0836 (0.0836)  evaluator_time: 0.0462 (0.0462)  time: 0.2068  data: 0.0731  max mem: 2850
# Test:  [59/60]  eta: 0:00:00  model_time: 0.0492 (0.0530)  evaluator_time: 0.0410 (0.0330)  time: 0.1744  data: 0.0773  max mem: 2850
# Test: Total time: 0:00:09 (0.1565 s / it)
# Averaged stats: model_time: 0.0492 (0.0530)  evaluator_time: 0.0410 (0.0330)
# Accumulating evaluation results...
# DONE (t=0.09s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.256
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.641
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.149
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.126
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.316
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.038
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.256
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.393
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.246
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.462
# Epoch: [4]  [  0/240]  eta: 0:01:19  lr: 0.000500  loss: 0.5781 (0.5781)  loss_classifier: 0.1469 (0.1469)  loss_box_reg: 0.3967 (0.3967)  loss_objectness: 0.0134 (0.0134)  loss_rpn_box_reg: 0.0211 (0.0211)  time: 0.3317  data: 0.1480  max mem: 2850
# Epoch: [4]  [ 10/240]  eta: 0:01:11  lr: 0.000500  loss: 0.7865 (0.7918)  loss_classifier: 0.2084 (0.2224)  loss_box_reg: 0.5424 (0.4963)  loss_objectness: 0.0381 (0.0446)  loss_rpn_box_reg: 0.0267 (0.0285)  time: 0.3122  data: 0.1448  max mem: 2850
# Epoch: [4]  [ 20/240]  eta: 0:01:04  lr: 0.000500  loss: 0.7476 (0.7222)  loss_classifier: 0.1913 (0.2035)  loss_box_reg: 0.4382 (0.4432)  loss_objectness: 0.0455 (0.0491)  loss_rpn_box_reg: 0.0254 (0.0264)  time: 0.2917  data: 0.1291  max mem: 2850
# Epoch: [4]  [ 30/240]  eta: 0:01:01  lr: 0.000500  loss: 0.6518 (0.7310)  loss_classifier: 0.1833 (0.2067)  loss_box_reg: 0.3918 (0.4471)  loss_objectness: 0.0463 (0.0500)  loss_rpn_box_reg: 0.0263 (0.0273)  time: 0.2856  data: 0.1260  max mem: 2850
# Epoch: [4]  [ 40/240]  eta: 0:00:58  lr: 0.000500  loss: 0.6419 (0.7018)  loss_classifier: 0.1793 (0.1975)  loss_box_reg: 0.4076 (0.4348)  loss_objectness: 0.0285 (0.0440)  loss_rpn_box_reg: 0.0217 (0.0255)  time: 0.2942  data: 0.1317  max mem: 2850
# Epoch: [4]  [ 50/240]  eta: 0:00:57  lr: 0.000500  loss: 0.6305 (0.7088)  loss_classifier: 0.1780 (0.2001)  loss_box_reg: 0.4076 (0.4388)  loss_objectness: 0.0266 (0.0432)  loss_rpn_box_reg: 0.0176 (0.0268)  time: 0.3090  data: 0.1477  max mem: 2850
# Epoch: [4]  [ 60/240]  eta: 0:00:54  lr: 0.000500  loss: 0.7835 (0.7238)  loss_classifier: 0.1972 (0.2029)  loss_box_reg: 0.4817 (0.4506)  loss_objectness: 0.0402 (0.0441)  loss_rpn_box_reg: 0.0216 (0.0263)  time: 0.3189  data: 0.1596  max mem: 2850
# Epoch: [4]  [ 70/240]  eta: 0:00:51  lr: 0.000500  loss: 0.7609 (0.7243)  loss_classifier: 0.2138 (0.2037)  loss_box_reg: 0.4817 (0.4496)  loss_objectness: 0.0380 (0.0448)  loss_rpn_box_reg: 0.0216 (0.0262)  time: 0.3009  data: 0.1404  max mem: 2850
# Epoch: [4]  [ 80/240]  eta: 0:00:47  lr: 0.000500  loss: 0.6864 (0.7220)  loss_classifier: 0.1910 (0.2037)  loss_box_reg: 0.4248 (0.4465)  loss_objectness: 0.0333 (0.0454)  loss_rpn_box_reg: 0.0205 (0.0264)  time: 0.2876  data: 0.1289  max mem: 2850
# Epoch: [4]  [ 90/240]  eta: 0:00:44  lr: 0.000500  loss: 0.6963 (0.7187)  loss_classifier: 0.1915 (0.2025)  loss_box_reg: 0.4472 (0.4455)  loss_objectness: 0.0328 (0.0451)  loss_rpn_box_reg: 0.0190 (0.0256)  time: 0.2878  data: 0.1249  max mem: 2850
# Epoch: [4]  [100/240]  eta: 0:00:42  lr: 0.000500  loss: 0.7479 (0.7238)  loss_classifier: 0.2044 (0.2037)  loss_box_reg: 0.4922 (0.4507)  loss_objectness: 0.0276 (0.0444)  loss_rpn_box_reg: 0.0174 (0.0251)  time: 0.3066  data: 0.1364  max mem: 2850
# Epoch: [4]  [110/240]  eta: 0:00:38  lr: 0.000500  loss: 0.7149 (0.7224)  loss_classifier: 0.1851 (0.2028)  loss_box_reg: 0.5067 (0.4514)  loss_objectness: 0.0330 (0.0436)  loss_rpn_box_reg: 0.0173 (0.0246)  time: 0.2998  data: 0.1302  max mem: 2850
# Epoch: [4]  [120/240]  eta: 0:00:35  lr: 0.000500  loss: 0.6910 (0.7272)  loss_classifier: 0.1851 (0.2039)  loss_box_reg: 0.4800 (0.4541)  loss_objectness: 0.0371 (0.0442)  loss_rpn_box_reg: 0.0229 (0.0249)  time: 0.2708  data: 0.1052  max mem: 2850
# Epoch: [4]  [130/240]  eta: 0:00:32  lr: 0.000500  loss: 0.6910 (0.7266)  loss_classifier: 0.1922 (0.2035)  loss_box_reg: 0.4655 (0.4538)  loss_objectness: 0.0351 (0.0442)  loss_rpn_box_reg: 0.0255 (0.0250)  time: 0.2780  data: 0.1128  max mem: 2850
# Epoch: [4]  [140/240]  eta: 0:00:29  lr: 0.000500  loss: 0.7056 (0.7288)  loss_classifier: 0.1922 (0.2037)  loss_box_reg: 0.4376 (0.4548)  loss_objectness: 0.0368 (0.0446)  loss_rpn_box_reg: 0.0255 (0.0257)  time: 0.2852  data: 0.1176  max mem: 2850
# Epoch: [4]  [150/240]  eta: 0:00:26  lr: 0.000500  loss: 0.6912 (0.7227)  loss_classifier: 0.1901 (0.2017)  loss_box_reg: 0.3937 (0.4503)  loss_objectness: 0.0476 (0.0452)  loss_rpn_box_reg: 0.0244 (0.0255)  time: 0.2973  data: 0.1287  max mem: 2850
# Epoch: [4]  [160/240]  eta: 0:00:23  lr: 0.000500  loss: 0.7007 (0.7285)  loss_classifier: 0.1898 (0.2032)  loss_box_reg: 0.4217 (0.4534)  loss_objectness: 0.0358 (0.0457)  loss_rpn_box_reg: 0.0229 (0.0262)  time: 0.3122  data: 0.1468  max mem: 2850
# Epoch: [4]  [170/240]  eta: 0:00:20  lr: 0.000500  loss: 0.7562 (0.7316)  loss_classifier: 0.2038 (0.2038)  loss_box_reg: 0.5038 (0.4561)  loss_objectness: 0.0351 (0.0454)  loss_rpn_box_reg: 0.0286 (0.0262)  time: 0.2800  data: 0.1147  max mem: 2850
# Epoch: [4]  [180/240]  eta: 0:00:17  lr: 0.000500  loss: 0.7372 (0.7322)  loss_classifier: 0.2006 (0.2035)  loss_box_reg: 0.4645 (0.4568)  loss_objectness: 0.0412 (0.0457)  loss_rpn_box_reg: 0.0216 (0.0262)  time: 0.2661  data: 0.1031  max mem: 2850
# Epoch: [4]  [190/240]  eta: 0:00:14  lr: 0.000500  loss: 0.7057 (0.7286)  loss_classifier: 0.1876 (0.2021)  loss_box_reg: 0.4420 (0.4556)  loss_objectness: 0.0249 (0.0450)  loss_rpn_box_reg: 0.0203 (0.0259)  time: 0.2706  data: 0.1106  max mem: 2850
# Epoch: [4]  [200/240]  eta: 0:00:11  lr: 0.000500  loss: 0.7481 (0.7312)  loss_classifier: 0.2069 (0.2029)  loss_box_reg: 0.4853 (0.4565)  loss_objectness: 0.0298 (0.0454)  loss_rpn_box_reg: 0.0248 (0.0263)  time: 0.3045  data: 0.1413  max mem: 2850
# Epoch: [4]  [210/240]  eta: 0:00:08  lr: 0.000500  loss: 0.7983 (0.7312)  loss_classifier: 0.2370 (0.2031)  loss_box_reg: 0.4853 (0.4564)  loss_objectness: 0.0486 (0.0454)  loss_rpn_box_reg: 0.0239 (0.0264)  time: 0.3054  data: 0.1441  max mem: 2850
# Epoch: [4]  [220/240]  eta: 0:00:05  lr: 0.000500  loss: 0.6026 (0.7248)  loss_classifier: 0.1819 (0.2011)  loss_box_reg: 0.3800 (0.4527)  loss_objectness: 0.0373 (0.0451)  loss_rpn_box_reg: 0.0205 (0.0261)  time: 0.2552  data: 0.0954  max mem: 2850
# Epoch: [4]  [230/240]  eta: 0:00:02  lr: 0.000500  loss: 0.6011 (0.7259)  loss_classifier: 0.1675 (0.2010)  loss_box_reg: 0.3800 (0.4537)  loss_objectness: 0.0373 (0.0450)  loss_rpn_box_reg: 0.0202 (0.0261)  time: 0.2601  data: 0.0994  max mem: 2850
# Epoch: [4]  [239/240]  eta: 0:00:00  lr: 0.000500  loss: 0.7204 (0.7273)  loss_classifier: 0.1856 (0.2015)  loss_box_reg: 0.4749 (0.4546)  loss_objectness: 0.0406 (0.0450)  loss_rpn_box_reg: 0.0219 (0.0261)  time: 0.2707  data: 0.1099  max mem: 2850
# Epoch: [4] Total time: 0:01:09 (0.2891 s / it)
# creating index...
# index created!
# Test:  [ 0/60]  eta: 0:00:18  model_time: 0.0848 (0.0848)  evaluator_time: 0.0887 (0.0887)  time: 0.3102  data: 0.1326  max mem: 2850
# Test:  [59/60]  eta: 0:00:00  model_time: 0.0623 (0.0588)  evaluator_time: 0.0495 (0.0417)  time: 0.2111  data: 0.0942  max mem: 2850
# Test: Total time: 0:00:11 (0.1834 s / it)
# Averaged stats: model_time: 0.0623 (0.0588)  evaluator_time: 0.0495 (0.0417)
# Accumulating evaluation results...
# DONE (t=0.08s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.266
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.666
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.162
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.136
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.326
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.039
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.262
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.396
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.251
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.465
# 60.813645095825194
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|██████████| 528M/528M [00:03<00:00, 161MB/s]
# 40
# Epoch: [0]  [  0/240]  eta: 0:01:47  lr: 0.000026  loss: 1.5785 (1.5785)  loss_classifier: 0.6728 (0.6728)  loss_box_reg: 0.1534 (0.1534)  loss_objectness: 0.7124 (0.7124)  loss_rpn_box_reg: 0.0399 (0.0399)  time: 0.4485  data: 0.1171  max mem: 2850
# Epoch: [0]  [ 10/240]  eta: 0:01:44  lr: 0.000235  loss: 1.4666 (1.4599)  loss_classifier: 0.6689 (0.6564)  loss_box_reg: 0.0447 (0.0562)  loss_objectness: 0.7038 (0.7036)  loss_rpn_box_reg: 0.0448 (0.0437)  time: 0.4551  data: 0.1675  max mem: 2850
# Epoch: [0]  [ 20/240]  eta: 0:01:32  lr: 0.000444  loss: 1.3928 (1.3799)  loss_classifier: 0.5658 (0.5567)  loss_box_reg: 0.0530 (0.0734)  loss_objectness: 0.6996 (0.7000)  loss_rpn_box_reg: 0.0495 (0.0498)  time: 0.4170  data: 0.1397  max mem: 2850
# Epoch: [0]  [ 30/240]  eta: 0:01:25  lr: 0.000653  loss: 1.2203 (1.3164)  loss_classifier: 0.3647 (0.4804)  loss_box_reg: 0.1031 (0.0910)  loss_objectness: 0.6887 (0.6924)  loss_rpn_box_reg: 0.0540 (0.0526)  time: 0.3782  data: 0.1045  max mem: 2850
# Epoch: [0]  [ 40/240]  eta: 0:01:21  lr: 0.000862  loss: 1.1339 (1.2651)  loss_classifier: 0.2805 (0.4297)  loss_box_reg: 0.1302 (0.1053)  loss_objectness: 0.6535 (0.6795)  loss_rpn_box_reg: 0.0414 (0.0506)  time: 0.3951  data: 0.1191  max mem: 2850
# Epoch: [0]  [ 50/240]  eta: 0:01:17  lr: 0.001071  loss: 1.0016 (1.2151)  loss_classifier: 0.2423 (0.3954)  loss_box_reg: 0.1339 (0.1153)  loss_objectness: 0.6054 (0.6562)  loss_rpn_box_reg: 0.0382 (0.0483)  time: 0.4136  data: 0.1399  max mem: 2850
# Epoch: [0]  [ 60/240]  eta: 0:01:12  lr: 0.001280  loss: 0.9516 (1.1757)  loss_classifier: 0.2286 (0.3757)  loss_box_reg: 0.1731 (0.1342)  loss_objectness: 0.5008 (0.6183)  loss_rpn_box_reg: 0.0382 (0.0475)  time: 0.3933  data: 0.1144  max mem: 2850
# Epoch: [0]  [ 70/240]  eta: 0:01:07  lr: 0.001489  loss: 0.9002 (1.1198)  loss_classifier: 0.2867 (0.3595)  loss_box_reg: 0.2355 (0.1562)  loss_objectness: 0.2573 (0.5555)  loss_rpn_box_reg: 0.0438 (0.0487)  time: 0.3764  data: 0.0883  max mem: 2850
# Epoch: [0]  [ 80/240]  eta: 0:01:04  lr: 0.001698  loss: 0.8020 (1.0777)  loss_classifier: 0.2797 (0.3487)  loss_box_reg: 0.2700 (0.1752)  loss_objectness: 0.1399 (0.5032)  loss_rpn_box_reg: 0.0562 (0.0506)  time: 0.4161  data: 0.1289  max mem: 2850
# Epoch: [0]  [ 90/240]  eta: 0:01:00  lr: 0.001907  loss: 0.7476 (1.0385)  loss_classifier: 0.2797 (0.3403)  loss_box_reg: 0.2695 (0.1852)  loss_objectness: 0.1170 (0.4621)  loss_rpn_box_reg: 0.0608 (0.0509)  time: 0.4162  data: 0.1348  max mem: 2850
# Epoch: [0]  [100/240]  eta: 0:00:56  lr: 0.002116  loss: 0.8172 (1.0177)  loss_classifier: 0.2923 (0.3367)  loss_box_reg: 0.2771 (0.1979)  loss_objectness: 0.1334 (0.4319)  loss_rpn_box_reg: 0.0564 (0.0511)  time: 0.3896  data: 0.1152  max mem: 2850
# Epoch: [0]  [110/240]  eta: 0:00:52  lr: 0.002325  loss: 0.8208 (1.0028)  loss_classifier: 0.3177 (0.3366)  loss_box_reg: 0.3017 (0.2095)  loss_objectness: 0.1361 (0.4059)  loss_rpn_box_reg: 0.0409 (0.0507)  time: 0.4147  data: 0.1411  max mem: 2850
# Epoch: [0]  [120/240]  eta: 0:00:48  lr: 0.002534  loss: 0.8208 (0.9879)  loss_classifier: 0.3085 (0.3328)  loss_box_reg: 0.3017 (0.2200)  loss_objectness: 0.1385 (0.3838)  loss_rpn_box_reg: 0.0409 (0.0512)  time: 0.4279  data: 0.1550  max mem: 2850
# Epoch: [0]  [130/240]  eta: 0:00:44  lr: 0.002743  loss: 0.7563 (0.9720)  loss_classifier: 0.2875 (0.3279)  loss_box_reg: 0.3239 (0.2287)  loss_objectness: 0.1371 (0.3641)  loss_rpn_box_reg: 0.0435 (0.0513)  time: 0.3949  data: 0.1216  max mem: 2850
# Epoch: [0]  [140/240]  eta: 0:00:40  lr: 0.002952  loss: 0.7208 (0.9596)  loss_classifier: 0.2525 (0.3236)  loss_box_reg: 0.3239 (0.2394)  loss_objectness: 0.0953 (0.3454)  loss_rpn_box_reg: 0.0435 (0.0512)  time: 0.3879  data: 0.0968  max mem: 2850
# Epoch: [0]  [150/240]  eta: 0:00:36  lr: 0.003161  loss: 0.7802 (0.9571)  loss_classifier: 0.2585 (0.3238)  loss_box_reg: 0.3393 (0.2483)  loss_objectness: 0.0942 (0.3320)  loss_rpn_box_reg: 0.0499 (0.0530)  time: 0.4241  data: 0.1360  max mem: 2850
# Epoch: [0]  [160/240]  eta: 0:00:32  lr: 0.003370  loss: 0.7612 (0.9456)  loss_classifier: 0.2656 (0.3203)  loss_box_reg: 0.3375 (0.2530)  loss_objectness: 0.1127 (0.3194)  loss_rpn_box_reg: 0.0535 (0.0530)  time: 0.4170  data: 0.1437  max mem: 2850
# Epoch: [0]  [170/240]  eta: 0:00:28  lr: 0.003579  loss: 0.7197 (0.9326)  loss_classifier: 0.2363 (0.3159)  loss_box_reg: 0.2885 (0.2576)  loss_objectness: 0.1100 (0.3062)  loss_rpn_box_reg: 0.0465 (0.0529)  time: 0.3921  data: 0.1214  max mem: 2850
# Epoch: [0]  [180/240]  eta: 0:00:24  lr: 0.003788  loss: 0.7643 (0.9309)  loss_classifier: 0.2663 (0.3149)  loss_box_reg: 0.3726 (0.2696)  loss_objectness: 0.0811 (0.2942)  loss_rpn_box_reg: 0.0443 (0.0523)  time: 0.4065  data: 0.1339  max mem: 2850
# Epoch: [0]  [190/240]  eta: 0:00:20  lr: 0.003997  loss: 0.9179 (0.9288)  loss_classifier: 0.3019 (0.3137)  loss_box_reg: 0.4693 (0.2788)  loss_objectness: 0.0811 (0.2840)  loss_rpn_box_reg: 0.0470 (0.0523)  time: 0.4054  data: 0.1322  max mem: 2850
# Epoch: [0]  [200/240]  eta: 0:00:16  lr: 0.004206  loss: 0.7543 (0.9217)  loss_classifier: 0.2658 (0.3114)  loss_box_reg: 0.3913 (0.2842)  loss_objectness: 0.0815 (0.2741)  loss_rpn_box_reg: 0.0486 (0.0519)  time: 0.3755  data: 0.1085  max mem: 2850
# Epoch: [0]  [210/240]  eta: 0:00:12  lr: 0.004415  loss: 0.7303 (0.9164)  loss_classifier: 0.2564 (0.3088)  loss_box_reg: 0.3555 (0.2896)  loss_objectness: 0.0805 (0.2661)  loss_rpn_box_reg: 0.0481 (0.0519)  time: 0.3715  data: 0.0997  max mem: 2850
# Epoch: [0]  [220/240]  eta: 0:00:08  lr: 0.004624  loss: 0.7303 (0.9072)  loss_classifier: 0.2388 (0.3053)  loss_box_reg: 0.3381 (0.2920)  loss_objectness: 0.0821 (0.2582)  loss_rpn_box_reg: 0.0484 (0.0517)  time: 0.4086  data: 0.1238  max mem: 2850
# Epoch: [0]  [230/240]  eta: 0:00:04  lr: 0.004833  loss: 0.6792 (0.9011)  loss_classifier: 0.2323 (0.3031)  loss_box_reg: 0.3207 (0.2961)  loss_objectness: 0.0821 (0.2503)  loss_rpn_box_reg: 0.0462 (0.0516)  time: 0.4110  data: 0.1283  max mem: 2850
# Epoch: [0]  [239/240]  eta: 0:00:00  lr: 0.005000  loss: 0.6767 (0.8964)  loss_classifier: 0.2060 (0.3009)  loss_box_reg: 0.3410 (0.2979)  loss_objectness: 0.0790 (0.2454)  loss_rpn_box_reg: 0.0503 (0.0522)  time: 0.3876  data: 0.1039  max mem: 2850
# Epoch: [0] Total time: 0:01:36 (0.4019 s / it)
# creating index...
# index created!
# Test:  [ 0/60]  eta: 0:00:20  model_time: 0.1411 (0.1411)  evaluator_time: 0.0862 (0.0862)  time: 0.3448  data: 0.1133  max mem: 2850
# Test:  [59/60]  eta: 0:00:00  model_time: 0.0916 (0.0925)  evaluator_time: 0.0381 (0.0332)  time: 0.2024  data: 0.0687  max mem: 2850
# Test: Total time: 0:00:11 (0.1944 s / it)
# Averaged stats: model_time: 0.0916 (0.0925)  evaluator_time: 0.0381 (0.0332)
# Accumulating evaluation results...
# DONE (t=0.09s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.123
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.418
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.027
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.049
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.155
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.023
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.138
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.290
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.195
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.334
# ...
# creating index...
# index created!
# Test:  [ 0/54]  eta: 0:00:23  model_time: 0.1611 (0.1611)  evaluator_time: 0.0066 (0.0066)  time: 0.4355  data: 0.2639  max mem: 2850
# Test:  [53/54]  eta: 0:00:00  model_time: 0.1082 (0.1095)  evaluator_time: 0.0153 (0.0155)  time: 0.3903  data: 0.2600  max mem: 2850
# Test: Total time: 0:00:22 (0.4147 s / it)
# Averaged stats: model_time: 0.1082 (0.1095)  evaluator_time: 0.0153 (0.0155)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.102
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.385
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.010
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.093
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.193
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.035
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.157
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.249
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.242
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.323
# Epoch: [3]  [  0/216]  eta: 0:02:11  lr: 0.000500  loss: 1.4870 (1.4870)  loss_classifier: 0.4918 (0.4918)  loss_box_reg: 0.5394 (0.5394)  loss_objectness: 0.3926 (0.3926)  loss_rpn_box_reg: 0.0631 (0.0631)  time: 0.6099  data: 0.3254  max mem: 2850
# Epoch: [3]  [ 10/216]  eta: 0:02:22  lr: 0.000500  loss: 1.1900 (1.0968)  loss_classifier: 0.3683 (0.3384)  loss_box_reg: 0.5394 (0.5512)  loss_objectness: 0.0821 (0.1137)  loss_rpn_box_reg: 0.0631 (0.0934)  time: 0.6917  data: 0.3805  max mem: 2850
# Epoch: [3]  [ 20/216]  eta: 0:02:09  lr: 0.000500  loss: 1.0046 (1.0397)  loss_classifier: 0.2812 (0.3158)  loss_box_reg: 0.5237 (0.5331)  loss_objectness: 0.0599 (0.1033)  loss_rpn_box_reg: 0.0596 (0.0875)  time: 0.6624  data: 0.3575  max mem: 2850
# Epoch: [3]  [ 30/216]  eta: 0:02:05  lr: 0.000500  loss: 0.9617 (0.9988)  loss_classifier: 0.2922 (0.3131)  loss_box_reg: 0.5258 (0.5205)  loss_objectness: 0.0505 (0.0877)  loss_rpn_box_reg: 0.0531 (0.0775)  time: 0.6655  data: 0.3587  max mem: 2850
# Epoch: [3]  [ 40/216]  eta: 0:01:55  lr: 0.000500  loss: 0.8593 (0.9571)  loss_classifier: 0.2732 (0.3036)  loss_box_reg: 0.4821 (0.5043)  loss_objectness: 0.0365 (0.0809)  loss_rpn_box_reg: 0.0308 (0.0683)  time: 0.6491  data: 0.3433  max mem: 2850
# Epoch: [3]  [ 50/216]  eta: 0:01:49  lr: 0.000500  loss: 0.9091 (0.9683)  loss_classifier: 0.2671 (0.3044)  loss_box_reg: 0.5039 (0.5214)  loss_objectness: 0.0450 (0.0765)  loss_rpn_box_reg: 0.0351 (0.0660)  time: 0.6389  data: 0.3340  max mem: 2850
# Epoch: [3]  [ 60/216]  eta: 0:01:41  lr: 0.000500  loss: 0.7715 (0.9331)  loss_classifier: 0.2622 (0.2950)  loss_box_reg: 0.4487 (0.5027)  loss_objectness: 0.0459 (0.0719)  loss_rpn_box_reg: 0.0326 (0.0635)  time: 0.6457  data: 0.3342  max mem: 2850
# Epoch: [3]  [ 70/216]  eta: 0:01:35  lr: 0.000500  loss: 0.7715 (0.9213)  loss_classifier: 0.2281 (0.2917)  loss_box_reg: 0.4272 (0.4996)  loss_objectness: 0.0471 (0.0697)  loss_rpn_box_reg: 0.0220 (0.0604)  time: 0.6429  data: 0.3215  max mem: 2850
# Epoch: [3]  [ 80/216]  eta: 0:01:28  lr: 0.000500  loss: 0.9064 (0.9234)  loss_classifier: 0.3100 (0.2936)  loss_box_reg: 0.5513 (0.5005)  loss_objectness: 0.0508 (0.0691)  loss_rpn_box_reg: 0.0301 (0.0602)  time: 0.6604  data: 0.3350  max mem: 2850
# Epoch: [3]  [ 90/216]  eta: 0:01:22  lr: 0.000500  loss: 0.9397 (0.9253)  loss_classifier: 0.3017 (0.2940)  loss_box_reg: 0.5473 (0.5049)  loss_objectness: 0.0489 (0.0666)  loss_rpn_box_reg: 0.0326 (0.0598)  time: 0.6402  data: 0.3336  max mem: 2850
# Epoch: [3]  [100/216]  eta: 0:01:15  lr: 0.000500  loss: 0.7867 (0.9154)  loss_classifier: 0.2640 (0.2899)  loss_box_reg: 0.4796 (0.5015)  loss_objectness: 0.0333 (0.0639)  loss_rpn_box_reg: 0.0491 (0.0601)  time: 0.6404  data: 0.3501  max mem: 2850
# Epoch: [3]  [110/216]  eta: 0:01:08  lr: 0.000500  loss: 0.9222 (0.9348)  loss_classifier: 0.2782 (0.2937)  loss_box_reg: 0.5851 (0.5117)  loss_objectness: 0.0323 (0.0683)  loss_rpn_box_reg: 0.0518 (0.0610)  time: 0.6258  data: 0.3393  max mem: 2850
# Epoch: [3]  [120/216]  eta: 0:01:02  lr: 0.000500  loss: 0.9977 (0.9448)  loss_classifier: 0.2901 (0.2959)  loss_box_reg: 0.5912 (0.5179)  loss_objectness: 0.0614 (0.0679)  loss_rpn_box_reg: 0.0555 (0.0630)  time: 0.6507  data: 0.3498  max mem: 2850
# Epoch: [3]  [130/216]  eta: 0:00:55  lr: 0.000500  loss: 0.9674 (0.9366)  loss_classifier: 0.2867 (0.2931)  loss_box_reg: 0.5385 (0.5155)  loss_objectness: 0.0541 (0.0665)  loss_rpn_box_reg: 0.0414 (0.0615)  time: 0.6473  data: 0.3537  max mem: 2850
# Epoch: [3]  [140/216]  eta: 0:00:49  lr: 0.000500  loss: 0.8443 (0.9315)  loss_classifier: 0.2617 (0.2903)  loss_box_reg: 0.5385 (0.5143)  loss_objectness: 0.0382 (0.0645)  loss_rpn_box_reg: 0.0375 (0.0625)  time: 0.6424  data: 0.3602  max mem: 2850
# Epoch: [3]  [150/216]  eta: 0:00:42  lr: 0.000500  loss: 0.8572 (0.9322)  loss_classifier: 0.2617 (0.2893)  loss_box_reg: 0.5499 (0.5168)  loss_objectness: 0.0382 (0.0630)  loss_rpn_box_reg: 0.0432 (0.0632)  time: 0.6306  data: 0.3358  max mem: 2850
# Epoch: [3]  [160/216]  eta: 0:00:36  lr: 0.000500  loss: 0.8572 (0.9313)  loss_classifier: 0.2784 (0.2889)  loss_box_reg: 0.5195 (0.5169)  loss_objectness: 0.0445 (0.0627)  loss_rpn_box_reg: 0.0429 (0.0627)  time: 0.6345  data: 0.3267  max mem: 2850
# Epoch: [3]  [170/216]  eta: 0:00:29  lr: 0.000500  loss: 0.8592 (0.9374)  loss_classifier: 0.2912 (0.2895)  loss_box_reg: 0.5090 (0.5232)  loss_objectness: 0.0390 (0.0614)  loss_rpn_box_reg: 0.0416 (0.0633)  time: 0.6558  data: 0.3482  max mem: 2850
# Epoch: [3]  [180/216]  eta: 0:00:23  lr: 0.000500  loss: 0.9315 (0.9327)  loss_classifier: 0.2895 (0.2877)  loss_box_reg: 0.5566 (0.5229)  loss_objectness: 0.0358 (0.0599)  loss_rpn_box_reg: 0.0361 (0.0622)  time: 0.6431  data: 0.3437  max mem: 2850
# Epoch: [3]  [190/216]  eta: 0:00:16  lr: 0.000500  loss: 0.9183 (0.9333)  loss_classifier: 0.2959 (0.2884)  loss_box_reg: 0.5456 (0.5237)  loss_objectness: 0.0368 (0.0597)  loss_rpn_box_reg: 0.0383 (0.0615)  time: 0.6615  data: 0.3619  max mem: 2850
# Epoch: [3]  [200/216]  eta: 0:00:10  lr: 0.000500  loss: 0.9589 (0.9319)  loss_classifier: 0.3150 (0.2877)  loss_box_reg: 0.5293 (0.5237)  loss_objectness: 0.0428 (0.0597)  loss_rpn_box_reg: 0.0418 (0.0608)  time: 0.6327  data: 0.3386  max mem: 2850
# Epoch: [3]  [210/216]  eta: 0:00:03  lr: 0.000500  loss: 0.8424 (0.9238)  loss_classifier: 0.2595 (0.2855)  loss_box_reg: 0.4943 (0.5186)  loss_objectness: 0.0429 (0.0593)  loss_rpn_box_reg: 0.0356 (0.0603)  time: 0.6446  data: 0.3642  max mem: 2850
# Epoch: [3]  [215/216]  eta: 0:00:00  lr: 0.000500  loss: 0.7863 (0.9207)  loss_classifier: 0.2561 (0.2851)  loss_box_reg: 0.4249 (0.5171)  loss_objectness: 0.0408 (0.0590)  loss_rpn_box_reg: 0.0299 (0.0595)  time: 0.6434  data: 0.3623  max mem: 2850
# Epoch: [3] Total time: 0:02:19 (0.6465 s / it)
# creating index...
# index created!
# Test:  [ 0/54]  eta: 0:00:24  model_time: 0.1649 (0.1649)  evaluator_time: 0.0048 (0.0048)  time: 0.4565  data: 0.2829  max mem: 2850
# Test:  [53/54]  eta: 0:00:00  model_time: 0.1086 (0.1095)  evaluator_time: 0.0138 (0.0171)  time: 0.4037  data: 0.2702  max mem: 2850
# Test: Total time: 0:00:22 (0.4181 s / it)
# Averaged stats: model_time: 0.1086 (0.1095)  evaluator_time: 0.0138 (0.0171)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.146
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.503
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.029
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.134
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.261
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.045
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.195
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.295
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.285
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.391
# Epoch: [4]  [  0/216]  eta: 0:02:15  lr: 0.000500  loss: 0.8082 (0.8082)  loss_classifier: 0.2761 (0.2761)  loss_box_reg: 0.4550 (0.4550)  loss_objectness: 0.0439 (0.0439)  loss_rpn_box_reg: 0.0331 (0.0331)  time: 0.6281  data: 0.3169  max mem: 2850
# Epoch: [4]  [ 10/216]  eta: 0:02:11  lr: 0.000500  loss: 0.8082 (0.8188)  loss_classifier: 0.2455 (0.2655)  loss_box_reg: 0.4550 (0.4323)  loss_objectness: 0.0495 (0.0633)  loss_rpn_box_reg: 0.0405 (0.0577)  time: 0.6407  data: 0.3300  max mem: 2850
# Epoch: [4]  [ 20/216]  eta: 0:02:00  lr: 0.000500  loss: 0.7147 (0.8042)  loss_classifier: 0.2366 (0.2526)  loss_box_reg: 0.4145 (0.4495)  loss_objectness: 0.0443 (0.0517)  loss_rpn_box_reg: 0.0360 (0.0503)  time: 0.6157  data: 0.3129  max mem: 2850
# Epoch: [4]  [ 30/216]  eta: 0:01:59  lr: 0.000500  loss: 0.8714 (0.8499)  loss_classifier: 0.2684 (0.2656)  loss_box_reg: 0.5034 (0.4929)  loss_objectness: 0.0300 (0.0443)  loss_rpn_box_reg: 0.0355 (0.0472)  time: 0.6446  data: 0.3472  max mem: 2850
# Epoch: [4]  [ 40/216]  eta: 0:01:51  lr: 0.000500  loss: 0.9089 (0.8760)  loss_classifier: 0.2966 (0.2704)  loss_box_reg: 0.5665 (0.5088)  loss_objectness: 0.0285 (0.0439)  loss_rpn_box_reg: 0.0355 (0.0528)  time: 0.6477  data: 0.3475  max mem: 2850
# Epoch: [4]  [ 50/216]  eta: 0:01:46  lr: 0.000500  loss: 0.9089 (0.8928)  loss_classifier: 0.2930 (0.2750)  loss_box_reg: 0.5812 (0.5216)  loss_objectness: 0.0339 (0.0456)  loss_rpn_box_reg: 0.0349 (0.0506)  time: 0.6456  data: 0.3480  max mem: 2850
# Epoch: [4]  [ 60/216]  eta: 0:01:39  lr: 0.000500  loss: 0.9857 (0.8858)  loss_classifier: 0.2784 (0.2720)  loss_box_reg: 0.5714 (0.5118)  loss_objectness: 0.0367 (0.0522)  loss_rpn_box_reg: 0.0323 (0.0499)  time: 0.6507  data: 0.3534  max mem: 2850
# Epoch: [4]  [ 70/216]  eta: 0:01:34  lr: 0.000500  loss: 0.8686 (0.8926)  loss_classifier: 0.2669 (0.2763)  loss_box_reg: 0.5604 (0.5144)  loss_objectness: 0.0437 (0.0517)  loss_rpn_box_reg: 0.0323 (0.0502)  time: 0.6447  data: 0.3403  max mem: 2850
# Epoch: [4]  [ 80/216]  eta: 0:01:26  lr: 0.000500  loss: 0.7970 (0.8716)  loss_classifier: 0.2581 (0.2712)  loss_box_reg: 0.4675 (0.5033)  loss_objectness: 0.0390 (0.0501)  loss_rpn_box_reg: 0.0294 (0.0470)  time: 0.6299  data: 0.3318  max mem: 2850
# Epoch: [4]  [ 90/216]  eta: 0:01:20  lr: 0.000500  loss: 0.7723 (0.8869)  loss_classifier: 0.2695 (0.2743)  loss_box_reg: 0.4871 (0.5113)  loss_objectness: 0.0390 (0.0517)  loss_rpn_box_reg: 0.0328 (0.0496)  time: 0.6114  data: 0.3195  max mem: 2850
# Epoch: [4]  [100/216]  eta: 0:01:14  lr: 0.000500  loss: 1.0815 (0.8927)  loss_classifier: 0.2814 (0.2737)  loss_box_reg: 0.6078 (0.5133)  loss_objectness: 0.0445 (0.0519)  loss_rpn_box_reg: 0.0509 (0.0539)  time: 0.6597  data: 0.3535  max mem: 2850
# Epoch: [4]  [110/216]  eta: 0:01:07  lr: 0.000500  loss: 1.0211 (0.9019)  loss_classifier: 0.2780 (0.2736)  loss_box_reg: 0.5100 (0.5169)  loss_objectness: 0.0441 (0.0531)  loss_rpn_box_reg: 0.0690 (0.0584)  time: 0.6499  data: 0.3447  max mem: 2850
# Epoch: [4]  [120/216]  eta: 0:01:01  lr: 0.000500  loss: 0.9079 (0.9035)  loss_classifier: 0.2782 (0.2750)  loss_box_reg: 0.4769 (0.5191)  loss_objectness: 0.0413 (0.0522)  loss_rpn_box_reg: 0.0490 (0.0571)  time: 0.6379  data: 0.3341  max mem: 2850
# Epoch: [4]  [130/216]  eta: 0:00:54  lr: 0.000500  loss: 0.8976 (0.9084)  loss_classifier: 0.2742 (0.2745)  loss_box_reg: 0.5553 (0.5263)  loss_objectness: 0.0353 (0.0508)  loss_rpn_box_reg: 0.0389 (0.0569)  time: 0.6330  data: 0.3209  max mem: 2850
# Epoch: [4]  [140/216]  eta: 0:00:48  lr: 0.000500  loss: 0.8976 (0.9115)  loss_classifier: 0.2701 (0.2741)  loss_box_reg: 0.5567 (0.5286)  loss_objectness: 0.0343 (0.0502)  loss_rpn_box_reg: 0.0377 (0.0587)  time: 0.6677  data: 0.3492  max mem: 2850
# Epoch: [4]  [150/216]  eta: 0:00:42  lr: 0.000500  loss: 0.8880 (0.9076)  loss_classifier: 0.2701 (0.2739)  loss_box_reg: 0.5537 (0.5257)  loss_objectness: 0.0334 (0.0501)  loss_rpn_box_reg: 0.0331 (0.0580)  time: 0.6760  data: 0.3645  max mem: 2850
# Epoch: [4]  [160/216]  eta: 0:00:36  lr: 0.000500  loss: 0.8537 (0.9099)  loss_classifier: 0.2753 (0.2747)  loss_box_reg: 0.5438 (0.5296)  loss_objectness: 0.0325 (0.0488)  loss_rpn_box_reg: 0.0267 (0.0568)  time: 0.6628  data: 0.3603  max mem: 2850
# Epoch: [4]  [170/216]  eta: 0:00:29  lr: 0.000500  loss: 0.8259 (0.9040)  loss_classifier: 0.2716 (0.2743)  loss_box_reg: 0.5014 (0.5250)  loss_objectness: 0.0415 (0.0488)  loss_rpn_box_reg: 0.0267 (0.0559)  time: 0.6375  data: 0.3385  max mem: 2850
# Epoch: [4]  [180/216]  eta: 0:00:23  lr: 0.000500  loss: 0.7689 (0.9002)  loss_classifier: 0.2493 (0.2736)  loss_box_reg: 0.4401 (0.5216)  loss_objectness: 0.0454 (0.0489)  loss_rpn_box_reg: 0.0306 (0.0561)  time: 0.6365  data: 0.3505  max mem: 2850
# Epoch: [4]  [190/216]  eta: 0:00:16  lr: 0.000500  loss: 0.8632 (0.8973)  loss_classifier: 0.2636 (0.2731)  loss_box_reg: 0.4897 (0.5201)  loss_objectness: 0.0365 (0.0484)  loss_rpn_box_reg: 0.0453 (0.0557)  time: 0.6502  data: 0.3550  max mem: 2850
# Epoch: [4]  [200/216]  eta: 0:00:10  lr: 0.000500  loss: 0.9185 (0.9024)  loss_classifier: 0.2669 (0.2748)  loss_box_reg: 0.5438 (0.5229)  loss_objectness: 0.0209 (0.0484)  loss_rpn_box_reg: 0.0425 (0.0563)  time: 0.6368  data: 0.3286  max mem: 2850
# Epoch: [4]  [210/216]  eta: 0:00:03  lr: 0.000500  loss: 1.0154 (0.9061)  loss_classifier: 0.2971 (0.2755)  loss_box_reg: 0.5600 (0.5248)  loss_objectness: 0.0312 (0.0486)  loss_rpn_box_reg: 0.0475 (0.0573)  time: 0.6603  data: 0.3457  max mem: 2850
# Epoch: [4]  [215/216]  eta: 0:00:00  lr: 0.000500  loss: 1.0137 (0.9059)  loss_classifier: 0.2964 (0.2747)  loss_box_reg: 0.6007 (0.5263)  loss_objectness: 0.0312 (0.0482)  loss_rpn_box_reg: 0.0448 (0.0568)  time: 0.6609  data: 0.3473  max mem: 2850
# Epoch: [4] Total time: 0:02:19 (0.6445 s / it)
# creating index...
# index created!
# Test:  [ 0/54]  eta: 0:00:24  model_time: 0.1645 (0.1645)  evaluator_time: 0.0046 (0.0046)  time: 0.4587  data: 0.2858  max mem: 2850
# Test:  [53/54]  eta: 0:00:00  model_time: 0.1096 (0.1101)  evaluator_time: 0.0176 (0.0182)  time: 0.4369  data: 0.2999  max mem: 2850
# Test: Total time: 0:00:23 (0.4323 s / it)
# Averaged stats: model_time: 0.1096 (0.1101)  evaluator_time: 0.0176 (0.0182)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.152
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.494
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.033
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.132
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.308
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.044
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.202
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.306
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.293
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.436
# 118.61626360575359

# %%
coco = evaluate(model, data_loader_test_wgisd, device=DEVICE)
# Out:
# creating index...
# index created!
# Test:  [ 0/60]  eta: 0:00:16  model_time: 0.1557 (0.1557)  evaluator_time: 0.0424 (0.0424)  time: 0.2736  data: 0.0716  max mem: 2850
# Test:  [59/60]  eta: 0:00:00  model_time: 0.1083 (0.1077)  evaluator_time: 0.0454 (0.0387)  time: 0.2543  data: 0.0869  max mem: 2850
# Test: Total time: 0:00:13 (0.2198 s / it)
# Averaged stats: model_time: 0.1083 (0.1077)  evaluator_time: 0.0454 (0.0387)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.149
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.485
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.041
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.065
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.188
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.023
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.171
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.291
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.161
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.352

# %%
import seaborn as sns
sns.set_theme()
plt.style.use('seaborn-paper')
backbones=["mobilenet","vgg16","vgg19","resnet18_fpn", "resnet50_fpn", "resnet101_fpn"]
#F1 = (2 * precision * recall)/(precision+recall)
for i in range(0,len(backbones)):
    all_precision = coco_tests_wgisd[i].coco_eval['bbox'].eval['precision']
    map = coco_tests_wgisd[i].coco_eval['bbox'].stats[1]

    pr_5 = all_precision[0, :, 0, 0, 2] # data for IoU@0.5
    x = np.arange(0, 1.01, 0.01)
    plt.plot(x, pr_5, label=backbones[i]+str(" {:.3f} mAP@0.5".format(map)), linewidth=2)

plt.legend(loc="best")
plt.xlim(0, 1)
plt.ylim(0, 1)
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.xticks(np.arange(0, 1.0001, 0.1))
plt.yticks(np.arange(0, 1.0001, 0.1))

plt.show()

#F1 = (2 * precision * recall)/(precision+recall)
for i in range(0,len(backbones)):
    all_precision = coco_tests_wgisd[i].coco_eval['bbox'].eval['precision']
    map = coco_tests_wgisd[i].coco_eval['bbox'].stats[1]
    map95= coco_tests_wgisd[i].coco_eval['bbox'].stats[0]
    print(backbones[i]+": mAP@50="+str(map)+ ", mAP@50:95="+str(map95)+ ", FPS="+str(1000/fps_tests_wgisd[i]))
    plt.plot(1000/fps_tests_wgisd[i], map, label=backbones[i], linewidth=2, marker='o')

plt.legend(loc="best")
plt.xlim((1000/max(fps_tests_wgisd))-1, 20)
plt.ylim(0.5, 1)
plt.title('COCO mAP - FPS')
plt.xlabel('FPS')
plt.ylabel('COCO mAP@0.5')
plt.xticks(np.arange(int(1000/max(fps_tests_wgisd)-3), int(20), 3))
plt.yticks(np.arange(0.5, 1.0001, 0.1))

plt.show()

plt.figure(figsize=(10,6))

#F1 = (2 * precision * recall)/(precision+recall)
maps50=[]
maps95=[]
for i in range(0,len(backbones)):
    all_precision = coco_tests_wgisd[i].coco_eval['bbox'].eval['precision']
    map = coco_tests_wgisd[i].coco_eval['bbox'].stats[1]
    maps50.append(map)
    map = coco_tests_wgisd[i].coco_eval['bbox'].stats[0]
    maps95.append(map)

x = backbones
plt.plot(x, maps50, label="mAP@50", color='r', linewidth=2, marker='o')
plt.plot(x, maps95, label="mAP@50:95", color='b', linewidth=2, marker='o')


plt.legend(loc="best")
plt.xlim(0, len(backbones)-1)
plt.ylim(0.3, 1)
plt.title('Faster RCNN Backbones Evaluation')
plt.xlabel('Backbones')
plt.ylabel('COCO mAP')
plt.xticks(np.arange(0, len(backbones), 1))
plt.yticks(np.arange(0.0, 1.0001, 0.1))

plt.show()



# the function takes the original prediction and the iou threshold.
def apply_nms(orig_prediction, iou_thresh=0.3):
    # torchvision returns the indices of the bboxes to keep
    keep = torchvision.ops.nms(orig_prediction['boxes'].cpu(), orig_prediction['scores'].cpu(), iou_thresh)

    final_prediction = orig_prediction
    final_prediction['boxes'] = final_prediction['boxes'].cpu()[keep]
    final_prediction['scores'] = final_prediction['scores'].cpu()[keep]
    final_prediction['labels'] = final_prediction['labels'].cpu()[keep]

    return final_prediction
# Out:
# <ipython-input-36-a894a8e946d6>:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-paper')
# mobilenet: mAP@50=0.6656300802256085, mAP@50:95=0.2655071411036369, FPS=16.443678033511745
# vgg16: mAP@50=0.6923899421087644, mAP@50:95=0.2966914916730177, FPS=9.487709012173067
# vgg19: mAP@50=0.7149076600099544, mAP@50:95=0.3012798892987216, FPS=8.039356822454815
# resnet18_fpn: mAP@50=0.7743650781212935, mAP@50:95=0.3582359997238067, FPS=16.53756614411371
# resnet50_fpn: mAP@50=0.797268017751261, mAP@50:95=0.40208875249109055, FPS=11.277612089539588
# resnet101_fpn: mAP@50=0.7726428603072665, mAP@50:95=0.3558961110855283, FPS=8.363273588051593

# %%
#F1 = (2 * precision * recall)/(precision+recall)
for i in range(0,len(backbones)):
    all_precision = coco_tests_wgrape[i].coco_eval['bbox'].eval['precision']
    map = coco_tests_wgrape[i].coco_eval['bbox'].stats[1]

    pr_5 = all_precision[0, :, 0, 0, 2] # data for IoU@0.5
    x = np.arange(0, 1.01, 0.01)
    plt.plot(x, pr_5, label=backbones[i]+str(" {:.3f} mAP@0.5".format(map)), linewidth=2)


plt.legend(loc="best")
plt.xlim(0, 1)
plt.ylim(0, 1)
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.xticks(np.arange(0, 1.0001, 0.1))
plt.yticks(np.arange(0, 1.0001, 0.1))

plt.show()

#F1 = (2 * precision * recall)/(precision+recall)
for i in range(0,len(backbones)):
    all_precision = coco_tests_wgrape[i].coco_eval['bbox'].eval['precision']
    map = coco_tests_wgrape[i].coco_eval['bbox'].stats[1]
    map95= coco_tests_wgrape[i].coco_eval['bbox'].stats[0]
    print(backbones[i]+": mAP@50="+str(map)+ ", mAP@50:95="+str(map95)+ ", FPS="+str(1000/fps_tests_wgrape[i]))
    plt.plot(1000/fps_tests_wgrape[i], map, label=backbones[i], linewidth=2, marker='o')

plt.legend(loc="best")
plt.xlim((1000/max(fps_tests_wgrape))-1, 1000/min(fps_tests_wgrape)+1)
plt.ylim(0.3, 1)
plt.title('COCO mAP - FPS')
plt.xlabel('FPS')
plt.ylabel('COCO mAP@0.5')
plt.xticks(np.arange(int(1000/max(fps_tests_wgrape)-3), int(1000/min(fps_tests_wgrape)+5), 3))
plt.yticks(np.arange(0.0, 1.0001, 0.1))

plt.show()

plt.figure(figsize=(10,6))

#F1 = (2 * precision * recall)/(precision+recall)
maps50=[]
maps95=[]
for i in range(0,len(backbones)):
    all_precision = coco_tests_wgrape[i].coco_eval['bbox'].eval['precision']
    map = coco_tests_wgrape[i].coco_eval['bbox'].stats[1]
    maps50.append(map)
    map = coco_tests_wgrape[i].coco_eval['bbox'].stats[0]
    maps95.append(map)

x = backbones
plt.plot(x, maps50, label="mAP@50", color='r', linewidth=2, marker='o')
plt.plot(x, maps95, label="mAP@50:95", color='b', linewidth=2, marker='o')


plt.legend(loc="best")
plt.xlim(0, len(backbones)-1)
plt.ylim(0.3, 1)
plt.title('Faster RCNN Backbones Evaluation')
plt.xlabel('Backbones')
plt.ylabel('COCO mAP')
plt.xticks(np.arange(0, len(backbones), 1))
plt.yticks(np.arange(0.0, 1.0001, 0.1))

plt.show()
# Out:
# mobilenet: mAP@50=0.1838743874870928, mAP@50:95=0.04991885271960942, FPS=15.244552293867605
# vgg16: mAP@50=0.31680428726922055, mAP@50:95=0.08514332669165857, FPS=9.601996835575322
# vgg19: mAP@50=0.31211832481444185, mAP@50:95=0.09199225824043682, FPS=8.168488540730644
# resnet18_fpn: mAP@50=0.4741510449017229, mAP@50:95=0.1308517963164254, FPS=16.46831019680122
# resnet50_fpn: mAP@50=0.5527306567087473, mAP@50:95=0.16584675607750762, FPS=11.22769580028963
# resnet101_fpn: mAP@50=0.49395039479551023, mAP@50:95=0.1517118958260066, FPS=8.430547123990626

# %%
img, target = dataset_test[1]
# put the model in evaluation mode
model.eval()
start_time = time.time()

with torch.no_grad():
    prediction = model([img.to(DEVICE)])[0]
# get the end time
end_time = time.time()
# get the fps
fps = 1 / (end_time - start_time)
print(fps)

print('MODEL OUTPUT\n')
nms_prediction = apply_nms(prediction, iou_thresh=0.3)

plot_img_bbox(img, target, nms_prediction)
# Out:
# 5.981762224358298
# MODEL OUTPUT
